# %% [markdown]
# # Optimizing NBA League Parity

# %%
# View of the new NBA teams here

# %% [markdown]
# ## What are we doing?

# %% [markdown]
# ## WTH is VORP?

# %% [markdown]
# ## Uh, ok, how bad is it?

# %%
# plot of VORP of teams best to worst for several years

# %% [markdown]
# Before we imported the data, we manually totaled players who were traded to their current team

# %%
# %matplotlib inline
import pandas as pd
import matplotlib

matplotlib.style.use('ggplot')

# %%
# Read in players and teams
df = pd.read_excel(io="2018stats.xlsx", sheetname="data", header=0, index_col=1)
df.head()
# Out:
#                     Rk Pos  Age   Tm  2016-7 mins  2016-7 VORP  2017-8 mins  \
# Player
# James Harden       181  SG   28  HOU         2947          9.0         1271
# LeBron James       224  PF   33  CLE         2794          7.3         1550
# Russell Westbrook  453  PG   29  OKC         2802         12.4         1553
# Chris Paul         356  PG   32  HOU         1921          5.3          763
# Stephen Curry      114  PG   29  GSW         2638          6.2          946
#
#                    2017-8 VORP  total_mins  total_vorp
# Player
# James Harden               3.9        4218        12.9
# LeBron James               4.8        4344        12.1
# Russell Westbrook          4.2        4355        16.6
# Chris Paul                 1.9        2684         7.2
# Stephen Curry              2.7        3584         8.9

# %% [markdown]
# Remove players with less than 300 minutes over the past two seasons

# %%
df = df[df.total_mins > 300]

# %%
Players = df.index.unique()
len(Players)
# Out:
# 389

# %%
Teams = df["Tm"].unique()
print(Teams)
# Out:
# ['HOU' 'CLE' 'OKC' 'GSW' 'SAS' 'DEN' 'MIL' 'LAC' 'TOR' 'MIN' 'NOP' 'UTA'
#  'MEM' 'POR' 'BOS' 'NYK' 'CHO' 'ORL' 'WAS' 'DET' 'PHI' 'MIA' 'LAL' 'DAL'
#  'ATL' 'PHO' 'SAC' 'BRK' 'IND' 'CHI']

# %%
player_cur_team=df["Tm"]
player_cur_team.head()
# Out:
# Player
# James Harden         HOU
# LeBron James         CLE
# Russell Westbrook    OKC
# Chris Paul           HOU
# Stephen Curry        GSW
# Name: Tm, dtype: object

# %% [markdown]
# But VORP is a product of playing time: the more time you have to play, the more opportunity you have to succeeed/fail. So we'll create a stat that standardizes each player based on the average value created per 1000 minutes: **"VORPper1000min"**

# %%
df["VORPper1000"]=(df["total_vorp"]/df["total_mins"])*1000

# %%
df["VORPper1000"].head()
# Out:
# Player
# James Harden         3.058321
# LeBron James         2.785451
# Russell Westbrook    3.811711
# Chris Paul           2.682563
# Stephen Curry        2.483259
# Name: VORPper1000, dtype: float64

# %%
focusStat = "total_vorp"

# %%
df[focusStat][df["Tm"]=="ATL"].sort_values(ascending=False)
# Out:
# Player
# Kent Bazemore            1.5
# Dewayne Dedmon           1.5
# Dennis Schroder          1.3
# Mike Muscala             1.1
# John Collins             0.8
# Ersan Ilyasova           0.5
# Tyler Cavanaugh          0.3
# Marco Belinelli          0.2
# Taurean Waller-Prince    0.2
# Nicolas Brussino         0.1
# Miles Plumlee            0.0
# Luke Babbitt            -0.1
# Isaiah Taylor           -0.5
# DeAndre' Bembry         -0.6
# Malcolm Delaney         -1.4
# Name: total_vorp, dtype: float64

# %%
plt = df.groupby(["Tm"]).sum()[focusStat].sort_values(ascending = False).plot(kind="bar")

# %% [markdown]
# ## So how are we going to fix it?

# %% [markdown]
# We're going to create a mixed integer program (MIP) to model the team assignments. Then, we'll optimize the distribution of players while following a few rules.

# %%
import gurobipy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-72-1a30be95fe9a> in <module>()
# ----> 1 import gurobipy
#
# C:\Users\Richard\Anaconda3\lib\site-packages\gurobipy\__init__.py in <module>()
# ----> 1 from .gurobipy import *
#
# ImportError: DLL load failed: The specified module could not be found.

# %% [markdown]
# ### Model Variables

# %%
# Instantiate the model
m = grb.Model()

# %%
# Binary Varable (1: player P is on team T, 0: otherwise)
player_assigned_to_team = {}
for t in Teams:
    for p in Players:
        player_assigned_to_team[p,t] = \
        m.addVar(vtype=grb.GRB.BINARY, 
                 name="player_{}_assigned_to_team_{}".format(p,t))

# %%
team_rating = {}
for t in Teams:
    m.addVar(vtype=grb.GRB.CONTINUOUS,
            name="total_VORP_of_team_{}".format(t))

# %%
min_team_rating = {}
min_team_rating = m.addVar(vtype=grb.GRB.CONTINUOUS,
                          name="minimum_team_rating")

# %%
max_team_rating = {}
max_team_rating = m.addVar(vtype=grb.GRB.CONTINUOUS,
                          name="maximum_team_rating")

# %%
m.update()

# %%
df["VORP"]["Stephen Curry"]
# Out:
# 9.8000000000000007

# %%
# Calculate min, max team ratings
for t in Teams:
    m.addConstr(sum(player_assigned_to_team[p,t]*df[focusStat][p] for p in Players)
               >= min_team_rating,
               name="min_rating_greater_than_team_{}".format(t))
    m.addConstr(sum(player_assigned_to_team[p,t]*df[focusStat][p] for p in Players)
               <= max_team_rating,
               name="max_rating_greater_than_team_{}".format(t))

# %%
# Each player must be assigned to a 1 and only 1 team
for p in Players:
    m.addConstr(sum(player_assigned_to_team[p,t] for t in Teams)==1,
               name="player_{}_may_only_be_on_one_team".format(p))

# %%
# Each team must have between 13 and 17 players
max_team_size = 17
min_team_size = 13

for t in Teams:
    m.addConstr(sum(player_assigned_to_team[p,t] for p in Players)
               >= min_team_size,
               name="team_{}_must_have_min_team_size".format(t))
    m.addConstr(sum(player_assigned_to_team[p,t] for p in Players)
               <= max_team_size,
               name="team_{}_must_have_max_team_size".format(t))

# %%
# each team must have this many of each position
# OK so Channing Frye is a PF-C and Sonny Weems is a SG-SF.
# Changing to PF and SG to make this easier

# %%
min_players_by_position = {}
min_players_by_position["PG"] = 2
min_players_by_position["SG"] = 2
min_players_by_position["SF"] = 2
min_players_by_position["PF"] = 2
min_players_by_position["C"] = 2

# %%
df["Pos"].loc["LeBron James"]
# Out:
# 'SF'

# %%
pos_dict = df["Pos"].to_dict()

# %%
pos_dict["LeBron James"] == "PG"
# Out:
# False

# %%
for pos in min_players_by_position:
    for t in Teams:
        m.addConstr(sum(player_assigned_to_team[p,t] for p in Players
                                                if pos_dict[p] == pos)
                   >= min_players_by_position[pos],
                name="team_{}_must_have_atleast_{}_{}".format(t,
                                               min_players_by_position[pos],
                                                             p))

# %%
def thisPlayerOnTeam(p,t):
    if(player_cur_team[p] == t):
        ret = 1
    else:
        ret = 0
    return ret

# %%
thisPlayerOnTeam("LeBron James","ATL")
# Out:
# 0

# %%
totalTrades = m.addVar(vtype=grb.GRB.CONTINUOUS, name='total num of trades')

# %%
m.update()

# %%
# calculate the sum total of player change
m.addConstr(sum(player_assigned_to_team[p,t]*thisPlayerOnTeam(p,t)
               for p in Players for t in Teams),grb.GRB.EQUAL, totalTrades,
               name="Total trades between teams")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# stipulate max team threshold
max_threshold = 0.001
m.addConstr(max_team_rating - min_team_rating <= max_threshold,
           name='force max threshold')
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
m.update()

# %%
m.setObjective(totalTrades)
m.ModelSense = grb.GRB.MAXIMIZE

# %%
#m.tune()

# %%
m.params.mipgap = 0.01
#m.params.symmetry = -1
# Out:
# Changed value of parameter MIPGap to 0.01
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001

# %%
m.optimize()
# Out:
# Optimize a model with 748 rows, 14313 columns and 83169 nonzeros
# Coefficient statistics:
#   Matrix range    [4e-05, 1e+00]
#   Objective range [1e+00, 1e+00]
#   Bounds range    [1e+00, 1e+00]
#   RHS range       [1e-03, 2e+01]
# Found heuristic solution: objective 12
# Presolve removed 2 rows and 32 columns
# Presolve time: 0.17s
# Presolved: 746 rows, 14281 columns, 82740 nonzeros
# Variable types: 1 continuous, 14280 integer (14280 binary)
#
# Root relaxation: objective 4.161949e+02, 3230 iterations, 0.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  416.19487    0   55   12.00000  416.19487  3368%     -    0s
# H    0     0                     407.0000000  416.19487  2.26%     -    2s
# H    0     0                     412.0000000  416.19487  1.02%     -    2s
#      0     0  416.06365    0   62  412.00000  416.06365  0.99%     -    2s
#
# Cutting planes:
#   MIR: 22
#   GUB cover: 3
#
# Explored 0 nodes (5659 simplex iterations) in 2.54 seconds
# Thread count was 8 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.120000000000e+02, best bound 4.160000000000e+02, gap 0.9709%

# %%
sol_player_assigned_to_team = {}
sol_player_assigned_to_team =\
        m.getAttr('X',player_assigned_to_team)

# %%
sol_player_assigned_to_team
# Out:
# {('C.J. Watson', 'UTA'): -0.0,
#  ('Chris Andersen', 'MIN'): 0.0,
#  ('Serge Ibaka', 'ORL'): 0.0,
#  ('Jodie Meeks', 'LAC'): -0.0,
#  ('Kawhi Leonard', 'PHO'): 0.0,
#  ('Jerami Grant', 'BRK'): 0.0,
#  ('Jeff Green', 'MIA'): 0.0,
#  ('T.J. Warren', 'IND'): 0.0,
#  ('Cory Joseph', 'BOS'): 0.0,
#  ('Terrence Jones', 'CHO'): 0.0,
#  ('Elfrid Payton', 'UTA'): 0.0,
#  ('Trey Burke', 'SAC'): -0.0,
#  ('Nate Robinson', 'HOU'): 0.0,
#  ('Willie Reed', 'LAC'): -0.0,
#  ('Paul Millsap', 'MIL'): 0.0,
#  ('Carl Landry', 'LAC'): 0.0,
#  ('Briante Weber', 'DAL'): -0.0,
#  ('Thaddeus Young', 'OKC'): 0.0,
#  ('DeJuan Blair', 'POR'): -0.0,
#  ('Jared Cunningham', 'GSW'): 0.0,
#  ('Mike Miller', 'WAS'): 0.0,
#  ('Jimmer Fredette', 'NYK'): 0.0,
#  ('Jordan McRae', 'BRK'): 0.0,
#  ('Axel Toupane', 'UTA'): -0.0,
#  ('Jose Calderon', 'WAS'): 0.0,
#  ('Kyle Singler', 'UTA'): 0.0,
#  ('Donald Sloan', 'WAS'): 0.0,
#  ('David Lee', 'NYK'): 0.0,
#  ('Tobias Harris', 'POR'): 0.0,
#  ('Leandro Barbosa', 'POR'): 0.0,
#  ('Omer Asik', 'LAL'): 0.0,
#  ('Anthony Davis', 'DAL'): 0.0,
#  ('Luol Deng', 'MEM'): 0.0,
#  ('Giannis Antetokounmpo', 'OKC'): 0.0,
#  ('Mason Plumlee', 'NOP'): -0.0,
#  ('Luis Scola', 'HOU'): -0.0,
#  ('Eric Gordon', 'SAS'): 0.0,
#  ('Maurice Harkless', 'MEM'): 0.0,
#  ('Damian Lillard', 'CLE'): 0.0,
#  ('Thomas Robinson', 'CHO'): -0.0,
#  ('Noah Vonleh', 'NOP'): 0.0,
#  ('Luis Montero', 'DEN'): -0.0,
#  ('Carmelo Anthony', 'UTA'): 0.0,
#  ('Russell Westbrook', 'MEM'): 0.0,
#  ('Lou Amundson', 'BRK'): 0.0,
#  ('Tyler Zeller', 'NYK'): 0.0,
#  ('Kosta Koufos', 'ORL'): 0.0,
#  ('Alexis Ajinca', 'NYK'): 0.0,
#  ('Donatas Motiejunas', 'MIN'): 0.0,
#  ('Kostas Papanikolaou', 'NOP'): 0.0,
#  ('Spencer Dinwiddie', 'DEN'): 0.0,
#  ('Evan Fournier', 'ATL'): 0.0,
#  ('Stephen Curry', 'DAL'): 0.0,
#  ('Quincy Acy', 'GSW'): 0.0,
#  ('Reggie Jackson', 'DEN'): 0.0,
#  ('Lavoy Allen', 'SAS'): 0.0,
#  ('Patrick Patterson', 'UTA'): 0.0,
#  ('Anthony Brown', 'WAS'): 0.0,
#  ('Josh McRoberts', 'SAS'): 0.0,
#  ('Bismack Biyombo', 'LAC'): 0.0,
#  ('O.J. Mayo', 'CHI'): 0.0,
#  ('Cole Aldrich', 'DET'): 0.0,
#  ('Kyle Singler', 'GSW'): 0.0,
#  ('Thanasis Antetokounmpo', 'TOR'): -0.0,
#  ('Nazr Mohammed', 'NOP'): 0.0,
#  ('Anthony Bennett', 'MIL'): 0.0,
#  ('Corey Brewer', 'UTA'): 0.0,
#  ('Langston Galloway', 'MEM'): 0.0,
#  ('Steve Novak', 'PHO'): 0.0,
#  ('Dwight Powell', 'IND'): 0.0,
#  ('Festus Ezeli', 'WAS'): 0.0,
#  ('Cory Joseph', 'ATL'): -0.0,
#  ('Jordan Mickey', 'SAC'): 0.0,
#  ('Rondae Hollis-Jefferson', 'ORL'): -0.0,
#  ('Darrun Hilliard', 'CHO'): 0.0,
#  ('Michael Carter-Williams', 'BRK'): 0.0,
#  ('Dion Waiters', 'ATL'): 0.0,
#  ('Rajon Rondo', 'IND'): 0.0,
#  ('Nik Stauskas', 'LAL'): 0.0,
#  ('Jabari Parker', 'TOR'): 0.0,
#  ('Trey Burke', 'BOS'): 0.0,
#  ('Greg Monroe', 'NYK'): 0.0,
#  ('Tony Allen', 'NOP'): 0.0,
#  ('Alonzo Gee', 'POR'): 0.0,
#  ('Derrick Favors', 'LAL'): 0.0,
#  ('James Young', 'BOS'): 1.0,
#  ('Bobby Portis', 'GSW'): 0.0,
#  ('Kentavious Caldwell-Pope', 'SAS'): 0.0,
#  ('Garrett Temple', 'PHO'): 0.0,
#  ('Mirza Teletovic', 'SAS'): 0.0,
#  ('Kristaps Porzingis', 'POR'): 0.0,
#  ('Luis Montero', 'UTA'): 0.0,
#  ('J.J. Barea', 'GSW'): 0.0,
#  ('Trey Burke', 'IND'): -0.0,
#  ('Austin Rivers', 'LAC'): 1.0,
#  ('Joakim Noah', 'MIL'): 0.0,
#  ('Blake Griffin', 'LAL'): 0.0,
#  ('LaMarcus Aldridge', 'GSW'): 0.0,
#  ('Lavoy Allen', 'DAL'): 0.0,
#  ('Marvin Williams', 'CHI'): 0.0,
#  ('Nikola Mirotic', 'UTA'): 0.0,
#  ('Jeremy Evans', 'NYK'): 0.0,
#  ('Kevin Garnett', 'DAL'): 0.0,
#  ('Chris Paul', 'PHI'): -0.0,
#  ('Joe Ingles', 'NYK'): 0.0,
#  ('Andrew Bogut', 'MEM'): -0.0,
#  ('Tayshaun Prince', 'LAL'): 0.0,
#  ('Dwyane Wade', 'NOP'): -0.0,
#  ('Jared Cunningham', 'WAS'): 0.0,
#  ('Marreese Speights', 'BRK'): 0.0,
#  ('Jabari Parker', 'LAC'): 0.0,
#  ('Kris Humphries', 'MIN'): 0.0,
#  ('Michael Carter-Williams', 'CHO'): 0.0,
#  ('Lou Amundson', 'NYK'): 1.0,
#  ('Nemanja Bjelica', 'SAS'): 0.0,
#  ('Luke Babbitt', 'CLE'): 0.0,
#  ('Serge Ibaka', 'MEM'): 0.0,
#  ('Andre Iguodala', 'NYK'): 0.0,
#  ('Cody Zeller', 'WAS'): -0.0,
#  ('Mirza Teletovic', 'OKC'): -0.0,
#  ('JaMychal Green', 'CHI'): 0.0,
#  ('Rakeem Christmas', 'WAS'): 0.0,
#  ('Justin Holiday', 'BOS'): 1.0,
#  ('Cameron Payne', 'TOR'): 0.0,
#  ('Dahntay Jones', 'IND'): 0.0,
#  ('T.J. Warren', 'MEM'): 0.0,
#  ('Jordan Hamilton', 'DEN'): 0.0,
#  ('Delon Wright', 'GSW'): 0.0,
#  ('Joffrey Lauvergne', 'MIL'): 0.0,
#  ('Tibor Pleiss', 'LAL'): 0.0,
#  ('Jason Terry', 'PHI'): 0.0,
#  ('Robin Lopez', 'DET'): 0.0,
#  ('Erick Green', 'DET'): 0.0,
#  ('Mike Muscala', 'PHI'): -0.0,
#  ('J.R. Smith', 'CHO'): 0.0,
#  ('Iman Shumpert', 'ATL'): 0.0,
#  ('Donatas Motiejunas', 'BOS'): -0.0,
#  ('Dion Waiters', 'GSW'): -0.0,
#  ('Cory Jefferson', 'NOP'): 0.0,
#  ('P.J. Tucker', 'MIN'): -0.0,
#  ('Goran Dragic', 'CHI'): 0.0,
#  ('Briante Weber', 'SAC'): -0.0,
#  ('Zaza Pachulia', 'SAS'): 0.0,
#  ('Dion Waiters', 'CHI'): 0.0,
#  ('Tarik Black', 'GSW'): 0.0,
#  ('Bryce Cotton', 'OKC'): 0.0,
#  ('Ed Davis', 'TOR'): 0.0,
#  ('Jarell Eddie', 'CHI'): 0.0,
#  ('Alex Len', 'HOU'): 0.0,
#  ('Donatas Motiejunas', 'IND'): -0.0,
#  ('Norris Cole', 'UTA'): 0.0,
#  ('T.J. Warren', 'SAC'): 0.0,
#  ('J.J. Barea', 'ATL'): 0.0,
#  ('Matthew Dellavedova', 'NOP'): 0.0,
#  ('Ty Lawson', 'CHI'): 1.0,
#  ('Jordan Hill', 'OKC'): 0.0,
#  ('Norman Powell', 'LAL'): -0.0,
#  ('Allen Crabbe', 'NYK'): -0.0,
#  ('Tyler Zeller', 'CHI'): 0.0,
#  ('Luc Mbah a Moute', 'PHO'): -0.0,
#  ('Kentavious Caldwell-Pope', 'LAC'): 0.0,
#  ('Cole Aldrich', 'ATL'): -0.0,
#  ('Nazr Mohammed', 'CLE'): 0.0,
#  ('Timofey Mozgov', 'CHI'): 0.0,
#  ('Tony Parker', 'NOP'): -0.0,
#  ('Lamar Patterson', 'LAC'): 0.0,
#  ('Aron Baynes', 'PHI'): -0.0,
#  ('Kyle Anderson', 'PHI'): 0.0,
#  ('Devyn Marble', 'PHI'): 0.0,
#  ('Jared Dudley', 'DET'): 0.0,
#  ('Jordan Clarkson', 'SAS'): 0.0,
#  ('Jason Terry', 'POR'): 0.0,
#  ('Kawhi Leonard', 'LAL'): -0.0,
#  ('Tyler Ennis', 'LAL'): 0.0,
#  ('Kobe Bryant', 'CHI'): 0.0,
#  ('Matt Barnes', 'WAS'): 0.0,
#  ('Tyus Jones', 'CLE'): -0.0,
#  ('Jarnell Stokes', 'LAC'): 0.0,
#  ('Clint Capela', 'OKC'): 0.0,
#  ('Eric Gordon', 'OKC'): 0.0,
#  ('Shabazz Muhammad', 'DAL'): -0.0,
#  ('LeBron James', 'NOP'): 0.0,
#  ('Rakeem Christmas', 'LAL'): 0.0,
#  ('Steven Adams', 'ATL'): 0.0,
#  ('Shabazz Napier', 'NYK'): 0.0,
#  ('Cory Joseph', 'SAC'): 0.0,
#  ('Al Jefferson', 'DAL'): 0.0,
#  ('Marcus Smart', 'ORL'): 0.0,
#  ('Tony Allen', 'WAS'): 0.0,
#  ('Jarell Eddie', 'MIN'): 0.0,
#  ('Tyler Johnson', 'ORL'): 0.0,
#  ('Greg Monroe', 'DEN'): 0.0,
#  ('Richard Jefferson', 'SAS'): 0.0,
#  ('Blake Griffin', 'LAC'): 1.0,
#  ('Alan Anderson', 'UTA'): -0.0,
#  ('Montrezl Harrell', 'BRK'): 0.0,
#  ('R.J. Hunter', 'MIN'): 0.0,
#  ('Jrue Holiday', 'DAL'): 0.0,
#  ('Draymond Green', 'OKC'): 0.0,
#  ('Jeff Ayres', 'MIN'): 0.0,
#  ('Bradley Beal', 'OKC'): -0.0,
#  ('Chris Copeland', 'TOR'): 0.0,
#  ('Terrence Ross', 'IND'): 0.0,
#  ('Terrence Jones', 'DAL'): 0.0,
#  ('Anderson Varejao', 'NYK'): 0.0,
#  ('Alonzo Gee', 'CLE'): 0.0,
#  ('Luke Babbitt', 'LAC'): 0.0,
#  ('Jeff Withey', 'MIL'): 0.0,
#  ('Coty Clarke', 'SAS'): -0.0,
#  ('Clint Capela', 'SAS'): 0.0,
#  ('K.J. McDaniels', 'ORL'): 0.0,
#  ('Cristiano Felicio', 'UTA'): 0.0,
#  ('Courtney Lee', 'GSW'): 0.0,
#  ('Josh Huestis', 'BOS'): -0.0,
#  ('Ramon Sessions', 'LAL'): 0.0,
#  ('Klay Thompson', 'MIL'): 0.0,
#  ('Shelvin Mack', 'DEN'): 0.0,
#  ('Cleanthony Early', 'UTA'): 0.0,
#  ('Tristan Thompson', 'NYK'): 0.0,
#  ('Kristaps Porzingis', 'BOS'): 0.0,
#  ('Quincy Acy', 'CLE'): 0.0,
#  ('P.J. Tucker', 'BOS'): 0.0,
#  ('Metta World Peace', 'WAS'): 0.0,
#  ('Kendall Marshall', 'MIN'): 0.0,
#  ('Reggie Bullock', 'LAC'): 0.0,
#  ('Mitch McGary', 'NOP'): 0.0,
#  ('Kyrie Irving', 'PHI'): -0.0,
#  ('Karl-Anthony Towns', 'OKC'): -0.0,
#  ('Reggie Bullock', 'PHI'): -0.0,
#  ('J.J. Hickson', 'SAC'): -0.0,
#  ('Cory Jefferson', 'OKC'): 0.0,
#  ('Andrew Nicholson', 'WAS'): 0.0,
#  ('Maurice Harkless', 'SAC'): 0.0,
#  ('Nikola Jokic', 'MIA'): 0.0,
#  ('Kyle Singler', 'BRK'): 0.0,
#  ('Andre Iguodala', 'NOP'): -0.0,
#  ('Jonathon Simmons', 'MEM'): -0.0,
#  ('Keith Appling', 'SAS'): -0.0,
#  ('Thanasis Antetokounmpo', 'ATL'): 0.0,
#  ('Elijah Millsap', 'OKC'): 0.0,
#  ('Jeremy Lin', 'OKC'): -0.0,
#  ('Jorge Gutierrez', 'ORL'): 0.0,
#  ('Steve Novak', 'LAL'): 0.0,
#  ("Amar'e Stoudemire", 'DEN'): 0.0,
#  ('Enes Kanter', 'PHI'): 0.0,
#  ('Gorgui Dieng', 'SAC'): 0.0,
#  ('Thabo Sefolosha', 'MIN'): 0.0,
#  ('Tyus Jones', 'LAC'): 0.0,
#  ('Darrun Hilliard', 'NOP'): 0.0,
#  ('J.R. Smith', 'SAC'): 0.0,
#  ('Alexis Ajinca', 'TOR'): 0.0,
#  ('Joffrey Lauvergne', 'HOU'): 0.0,
#  ('J.R. Smith', 'ATL'): 0.0,
#  ('Damian Lillard', 'POR'): 1.0,
#  ('Tyson Chandler', 'BOS'): 0.0,
#  ('JaMychal Green', 'DET'): 0.0,
#  ('Tyler Johnson', 'DAL'): 0.0,
#  ('Chris Andersen', 'ORL'): 0.0,
#  ('Kyle Lowry', 'TOR'): 1.0,
#  ('Lance Thomas', 'MEM'): 0.0,
#  ('Joe Ingles', 'MIL'): 0.0,
#  ('Walter Tavares', 'ORL'): -0.0,
#  ('Walter Tavares', 'BRK'): -0.0,
#  ('Blake Griffin', 'PHO'): 0.0,
#  ('Caron Butler', 'HOU'): 0.0,
#  ('Marcus Smart', 'DEN'): 0.0,
#  ('Jusuf Nurkic', 'CHI'): 0.0,
#  ('Anthony Brown', 'IND'): -0.0,
#  ('Kyle Anderson', 'HOU'): 0.0,
#  ('Rudy Gobert', 'LAL'): 0.0,
#  ('Kelly Olynyk', 'MIN'): 0.0,
#  ('Khris Middleton', 'NYK'): 0.0,
#  ('Udonis Haslem', 'PHO'): 0.0,
#  ('Phil Pressey', 'LAC'): 0.0,
#  ('Luc Mbah a Moute', 'CLE'): 0.0,
#  ('Jordan Adams', 'UTA'): 0.0,
#  ('Dwight Powell', 'PHI'): 0.0,
#  ('Seth Curry', 'MIN'): -0.0,
#  ('Courtney Lee', 'ORL'): 0.0,
#  ('Archie Goodwin', 'IND'): 0.0,
#  ('Coty Clarke', 'PHI'): 0.0,
#  ('Boris Diaw', 'DAL'): 0.0,
#  ('Dahntay Jones', 'PHO'): -0.0,
#  ('Stanley Johnson', 'NOP'): 0.0,
#  ('C.J. Miles', 'LAL'): -0.0,
#  ('Larry Nance Jr.', 'SAS'): 0.0,
#  ('Patrick Beverley', 'IND'): 0.0,
#  ('Sasha Kaun', 'BOS'): -0.0,
#  ('James Young', 'PHI'): 0.0,
#  ('Henry Sims', 'LAC'): 0.0,
#  ('Thabo Sefolosha', 'DEN'): -0.0,
#  ('Markieff Morris', 'DET'): 0.0,
#  ('Archie Goodwin', 'BOS'): -0.0,
#  ('Lorenzo Brown', 'DET'): 0.0,
#  ('Anthony Tolliver', 'SAC'): 0.0,
#  ('Nikola Mirotic', 'CHI'): 1.0,
#  ('Xavier Munford', 'DET'): -0.0,
#  ('Cory Jefferson', 'SAS'): -0.0,
#  ('James Harden', 'BRK'): -0.0,
#  ('D.J. Augustin', 'MIN'): 0.0,
#  ('Greivis Vasquez', 'MIL'): 1.0,
#  ('K.J. McDaniels', 'NOP'): 0.0,
#  ('Keith Appling', 'LAC'): 0.0,
#  ('Alan Anderson', 'ORL'): -0.0,
#  ('J.J. Hickson', 'IND'): -0.0,
#  ('Elliot Williams', 'SAC'): 0.0,
#  ('Luol Deng', 'SAS'): 0.0,
#  ('Justin Anderson', 'ORL'): 0.0,
#  ('Kirk Hinrich', 'NYK'): 0.0,
#  ('Reggie Jackson', 'CHI'): 0.0,
#  ('Trevor Ariza', 'SAS'): 0.0,
#  ('Karl-Anthony Towns', 'PHI'): -0.0,
#  ('Joe Ingles', 'OKC'): 0.0,
#  ('David West', 'MIN'): -0.0,
#  ('Briante Weber', 'OKC'): -0.0,
#  ('Jonas Valanciunas', 'IND'): 0.0,
#  ('Tim Frazier', 'IND'): 0.0,
#  ('Rodney Stuckey', 'MIL'): 0.0,
#  ('Quincy Acy', 'CHI'): 0.0,
#  ('Emmanuel Mudiay', 'MEM'): 0.0,
#  ('JaVale McGee', 'DET'): 0.0,
#  ('Nerlens Noel', 'MIA'): 0.0,
#  ('Devin Harris', 'LAL'): -0.0,
#  ('Rasual Butler', 'SAS'): 1.0,
#  ('Aaron Harrison', 'MIN'): 0.0,
#  ('C.J. Watson', 'WAS'): 0.0,
#  ('Joseph Young', 'WAS'): 0.0,
#  ('Cody Zeller', 'BRK'): 0.0,
#  ('Robert Sacre', 'MIN'): 0.0,
#  ('Mike Muscala', 'GSW'): 0.0,
#  ('Pat Connaughton', 'SAS'): 0.0,
#  ('Kirk Hinrich', 'UTA'): 0.0,
#  ('Wayne Ellington', 'WAS'): 0.0,
#  ('Andre Roberson', 'IND'): 0.0,
#  ('Bismack Biyombo', 'LAL'): -0.0,
#  ('Jeff Teague', 'SAS'): 0.0,
#  ('Dirk Nowitzki', 'ATL'): -0.0,
#  ('Deron Williams', 'CHI'): 0.0,
#  ('Delon Wright', 'PHI'): 0.0,
#  ('Lou Amundson', 'SAC'): 0.0,
#  ('Montrezl Harrell', 'MIN'): 0.0,
#  ('Phil Pressey', 'CLE'): 0.0,
#  ('Raul Neto', 'PHI'): 0.0,
#  ('Kostas Papanikolaou', 'DAL'): 0.0,
#  ('Jarrett Jack', 'CLE'): 0.0,
#  ('Jared Dudley', 'MIL'): 0.0,
#  ('Zaza Pachulia', 'BRK'): 0.0,
#  ('Kosta Koufos', 'MIL'): 0.0,
#  ('Kenneth Faried', 'CHI'): 0.0,
#  ('Leandro Barbosa', 'GSW'): 1.0,
#  ('Chris Bosh', 'SAC'): 0.0,
#  ('Rudy Gay', 'GSW'): 0.0,
#  ('Terrence Ross', 'WAS'): 0.0,
#  ('Norris Cole', 'WAS'): 0.0,
#  ('John Henson', 'IND'): 0.0,
#  ('John Jenkins', 'GSW'): 0.0,
#  ('Ian Clark', 'MEM'): 0.0,
#  ('J.J. Redick', 'OKC'): -0.0,
#  ('Cory Jefferson', 'LAL'): 0.0,
#  ('Alex Stepheson', 'DAL'): 0.0,
#  ('Duje Dukan', 'UTA'): 0.0,
#  ('Damian Lillard', 'MIA'): 0.0,
#  ('Jarell Eddie', 'POR'): 0.0,
#  ('JaVale McGee', 'SAC'): -0.0,
#  ('R.J. Hunter', 'DET'): -0.0,
#  ('Jonas Valanciunas', 'DEN'): 0.0,
#  ('Brook Lopez', 'WAS'): 0.0,
#  ('John Wall', 'PHO'): -0.0,
#  ('Henry Sims', 'SAS'): 0.0,
#  ('Jimmer Fredette', 'SAC'): 0.0,
#  ('Trey Burke', 'TOR'): 0.0,
#  ('Jahlil Okafor', 'BOS'): 0.0,
#  ('Phil Pressey', 'ORL'): 0.0,
#  ('LeBron James', 'BOS'): 0.0,
#  ('Xavier Munford', 'MIA'): -0.0,
#  ('Isaiah Thomas', 'OKC'): 0.0,
#  ('Dion Waiters', 'WAS'): 0.0,
#  ('Emmanuel Mudiay', 'IND'): 0.0,
#  ('Steve Blake', 'MIA'): 0.0,
#  ('Devin Booker', 'UTA'): -0.0,
#  ('Seth Curry', 'MIA'): 0.0,
#  ('Kelly Oubre', 'MIA'): 0.0,
#  ('Willie Reed', 'LAL'): 0.0,
#  ('Alec Burks', 'PHO'): 0.0,
#  ('Jared Dudley', 'DAL'): 0.0,
#  ('Al Horford', 'GSW'): 0.0,
#  ('Ty Lawson', 'CLE'): 0.0,
#  ('Elton Brand', 'CHO'): 0.0,
#  ('Kemba Walker', 'LAC'): 0.0,
#  ('Andre Iguodala', 'ATL'): -0.0,
#  ('Christian Wood', 'WAS'): 0.0,
#  ('Udonis Haslem', 'NOP'): 0.0,
#  ('Jonas Jerebko', 'DET'): 0.0,
#  ('Stephen Curry', 'ORL'): 0.0,
#  ('Joakim Noah', 'ATL'): 0.0,
#  ('Shelvin Mack', 'TOR'): 0.0,
#  ('Julius Randle', 'MIA'): 0.0,
#  ('Blake Griffin', 'NOP'): 0.0,
#  ('Kentavious Caldwell-Pope', 'BRK'): -0.0,
#  ('Jordan Farmar', 'NOP'): 0.0,
#  ('Dirk Nowitzki', 'DET'): 0.0,
#  ('Norman Powell', 'TOR'): 1.0,
#  ('R.J. Hunter', 'SAC'): 0.0,
#  ('Richard Jefferson', 'MIL'): 0.0,
#  ('Kevin Garnett', 'BOS'): 0.0,
#  ('Trey Burke', 'MIN'): -0.0,
#  ('Tiago Splitter', 'SAS'): 0.0,
#  ('Steve Blake', 'DET'): 1.0,
#  ('Andre Roberson', 'MIA'): 0.0,
#  ('Raul Neto', 'WAS'): 0.0,
#  ('Al Jefferson', 'MIN'): 0.0,
#  ('Ray McCallum', 'MEM'): 0.0,
#  ('Bobby Portis', 'IND'): 0.0,
#  ('Andrew Nicholson', 'POR'): 0.0,
#  ('Jeremy Lamb', 'OKC'): 0.0,
#  ('Dirk Nowitzki', 'DEN'): 0.0,
#  ('Kevin Garnett', 'IND'): 0.0,
#  ('Jrue Holiday', 'MIN'): -0.0,
#  ('Monta Ellis', 'PHI'): 0.0,
#  ('Derrick Rose', 'CHO'): -0.0,
#  ('Andrew Goudelock', 'BOS'): -0.0,
#  ('Frank Kaminsky', 'MIL'): 0.0,
#  ('Greg Monroe', 'SAS'): 0.0,
#  ('John Wall', 'MIA'): 0.0,
#  ('Jordan McRae', 'WAS'): 0.0,
#  ('Jarell Martin', 'ATL'): 0.0,
#  ('Tyler Zeller', 'GSW'): 0.0,
#  ('Meyers Leonard', 'CHO'): 0.0,
#  ('Jeff Teague', 'POR'): 0.0,
#  ('Willie Cauley-Stein', 'CLE'): 0.0,
#  ('Will Barton', 'SAC'): 0.0,
#  ('Wesley Johnson', 'DAL'): 0.0,
#  ('Nazr Mohammed', 'LAL'): 0.0,
#  ('Rodney Hood', 'POR'): 0.0,
#  ('Aaron Brooks', 'BOS'): 0.0,
#  ('Russ Smith', 'MEM'): 1.0,
#  ('Jared Sullinger', 'BOS'): 1.0,
#  ('Kent Bazemore', 'WAS'): 0.0,
#  ('Brandon Jennings', 'NYK'): 0.0,
#  ('Emmanuel Mudiay', 'CHI'): -0.0,
#  ('James Jones', 'LAC'): 0.0,
#  ('Vince Carter', 'UTA'): 0.0,
#  ('Derrick Rose', 'OKC'): 0.0,
#  ('Luke Babbitt', 'DAL'): -0.0,
#  ('Festus Ezeli', 'NYK'): 0.0,
#  ('Lucas Nogueira', 'WAS'): -0.0,
#  ('Shane Larkin', 'SAC'): -0.0,
#  ('Tony Snell', 'ATL'): 0.0,
#  ('O.J. Mayo', 'POR'): 0.0,
#  ('Jared Sullinger', 'IND'): 0.0,
#  ('Kevin Love', 'UTA'): 0.0,
#  ('Troy Daniels', 'ATL'): 0.0,
#  ('Steve Blake', 'SAC'): 0.0,
#  ('Jabari Parker', 'BRK'): 0.0,
#  ('Kyle Singler', 'PHO'): 0.0,
#  ('Miles Plumlee', 'HOU'): 0.0,
#  ('Rudy Gobert', 'SAC'): 0.0,
#  ('Delon Wright', 'IND'): 0.0,
#  ('Hassan Whiteside', 'SAC'): 0.0,
#  ('Evan Turner', 'HOU'): -0.0,
#  ('Chuck Hayes', 'MIL'): 0.0,
#  ('Brandon Knight', 'NOP'): -0.0,
#  ('Jeremy Evans', 'DEN'): 0.0,
#  ('Robert Sacre', 'SAC'): 0.0,
#  ('Jason Terry', 'IND'): 0.0,
#  ('Tiago Splitter', 'IND'): 0.0,
#  ('James Harden', 'ATL'): -0.0,
#  ('Dahntay Jones', 'LAL'): 0.0,
#  ('Pau Gasol', 'MIL'): 0.0,
#  ('Chris Johnson', 'GSW'): 0.0,
#  ('C.J. Miles', 'PHO'): 0.0,
#  ('Joakim Noah', 'SAS'): 0.0,
#  ('Timofey Mozgov', 'SAC'): 0.0,
#  ('DeMarre Carroll', 'PHO'): 0.0,
#  ('Raul Neto', 'HOU'): 0.0,
#  ('Branden Dawson', 'CHI'): 0.0,
#  ('Ryan Hollins', 'POR'): 0.0,
#  ('Derrick Favors', 'DEN'): 0.0,
#  ('Channing Frye', 'ATL'): 0.0,
#  ('Steven Adams', 'TOR'): 0.0,
#  ('Luc Mbah a Moute', 'HOU'): -0.0,
#  ('Patrick Patterson', 'MIN'): -0.0,
#  ('Jeremy Lamb', 'IND'): 0.0,
#  ('Gary Harris', 'LAL'): 0.0,
#  ('Gerald Green', 'CHO'): 0.0,
#  ('Brook Lopez', 'NOP'): 0.0,
#  ('Kendall Marshall', 'GSW'): 0.0,
#  ('Jordan Adams', 'GSW'): 0.0,
#  ('Emmanuel Mudiay', 'TOR'): 0.0,
#  ('Gary Neal', 'UTA'): 0.0,
#  ('LeBron James', 'PHO'): 0.0,
#  ('Jerami Grant', 'SAS'): 0.0,
#  ('James Harden', 'BOS'): 0.0,
#  ('Justin Holiday', 'CHI'): 0.0,
#  ('Pat Connaughton', 'IND'): 0.0,
#  ('Austin Rivers', 'MIN'): 0.0,
#  ('Jae Crowder', 'UTA'): 0.0,
#  ('Cory Jefferson', 'ATL'): 0.0,
#  ('Chris Bosh', 'PHI'): 0.0,
#  ('Ronnie Price', 'DEN'): -0.0,
#  ('Rondae Hollis-Jefferson', 'BOS'): 0.0,
#  ('J.J. Barea', 'CHI'): 0.0,
#  ('Iman Shumpert', 'MIN'): 0.0,
#  ('Blake Griffin', 'OKC'): 0.0,
#  ('Will Barton', 'PHO'): 0.0,
#  ('Jimmy Butler', 'SAS'): 0.0,
#  ('Tim Hardaway', 'POR'): 0.0,
#  ('Cameron Payne', 'MIL'): 0.0,
#  ('Amir Johnson', 'LAL'): -0.0,
#  ('Justin Harper', 'HOU'): 0.0,
#  ('Terrence Jones', 'NOP'): 0.0,
#  ('Jamal Crawford', 'NOP'): 0.0,
#  ('Tyreke Evans', 'DET'): 0.0,
#  ('Cliff Alexander', 'IND'): -0.0,
#  ('Pau Gasol', 'DAL'): 0.0,
#  ('Jerami Grant', 'OKC'): 0.0,
#  ('T.J. McConnell', 'PHO'): 0.0,
#  ('Rodney Hood', 'SAS'): 0.0,
#  ('Andre Iguodala', 'MEM'): -0.0,
#  ('Markieff Morris', 'WAS'): 0.0,
#  ('Ray McCallum', 'POR'): 0.0,
#  ('Anthony Brown', 'MEM'): 0.0,
#  ('Thaddeus Young', 'GSW'): 0.0,
#  ('Walter Tavares', 'ATL'): 1.0,
#  ('Jeremy Evans', 'DAL'): 1.0,
#  ('Marco Belinelli', 'DEN'): 0.0,
#  ('Marcin Gortat', 'NYK'): -0.0,
#  ('Carmelo Anthony', 'OKC'): 0.0,
#  ('Alex Len', 'MIL'): 0.0,
#  ('Jonas Jerebko', 'CLE'): 0.0,
#  ('Mason Plumlee', 'UTA'): 0.0,
#  ('Jodie Meeks', 'CHO'): 0.0,
#  ('Isaiah Thomas', 'CHI'): 0.0,
#  ('Jimmy Butler', 'DEN'): 0.0,
#  ('Kevin Martin', 'BOS'): 0.0,
#  ('Anthony Morrow', 'DET'): 0.0,
#  ('Bojan Bogdanovic', 'DAL'): -0.0,
#  ('Darren Collison', 'CLE'): 0.0,
#  ('DeMarre Carroll', 'MIA'): 0.0,
#  ('Tyreke Evans', 'CHI'): 0.0,
#  ('Giannis Antetokounmpo', 'GSW'): 0.0,
#  ('Charlie Villanueva', 'ATL'): 0.0,
#  ('Andre Iguodala', 'DAL'): 0.0,
#  ('Paul Pierce', 'MIA'): -0.0,
#  ('Cody Zeller', 'POR'): 0.0,
#  ('James Michael McAdoo', 'PHO'): 0.0,
#  ('Tyreke Evans', 'SAS'): 0.0,
#  ('Rudy Gobert', 'IND'): 0.0,
#  ('Tyler Zeller', 'MIN'): 0.0,
#  ('Sasha Kaun', 'MIL'): 0.0,
#  ('Allen Crabbe', 'IND'): 0.0,
#  ('Karl-Anthony Towns', 'MIL'): 0.0,
#  ('Darrun Hilliard', 'DAL'): 0.0,
#  ('C.J. Watson', 'IND'): 0.0,
#  ('Anthony Tolliver', 'PHI'): 0.0,
#  ("Amar'e Stoudemire", 'MIA'): 1.0,
#  ('Justin Anderson', 'NOP'): 0.0,
#  ('Austin Rivers', 'CHO'): 0.0,
#  ('C.J. McCollum', 'SAS'): 0.0,
#  ('Courtney Lee', 'IND'): 0.0,
#  ('Jarnell Stokes', 'BRK'): 0.0,
#  ('Jordan Mickey', 'BRK'): 0.0,
#  ('Noah Vonleh', 'GSW'): 0.0,
#  ('James Jones', 'POR'): 0.0,
#  ('Nerlens Noel', 'SAS'): 0.0,
#  ('Al Horford', 'CLE'): 0.0,
#  ('Cory Jefferson', 'DAL'): 0.0,
#  ('Ty Lawson', 'GSW'): 0.0,
#  ('Anthony Brown', 'NYK'): 0.0,
#  ('Jodie Meeks', 'BRK'): 0.0,
#  ('Chris Andersen', 'SAC'): 0.0,
#  ('Chris Paul', 'MIA'): 0.0,
#  ('Rodney Stuckey', 'SAC'): 0.0,
#  ('Marcelo Huertas', 'MIN'): 0.0,
#  ('Zach LaVine', 'DEN'): -0.0,
#  ('Anthony Morrow', 'SAC'): 0.0,
#  ('Giannis Antetokounmpo', 'UTA'): 0.0,
#  ('Tobias Harris', 'CHI'): 0.0,
#  ('Otto Porter', 'MEM'): 0.0,
#  ('Alec Burks', 'MEM'): 0.0,
#  ('Bryce Cotton', 'NYK'): 0.0,
#  ('Chris Bosh', 'CHI'): 0.0,
#  ('Anthony Bennett', 'DEN'): 0.0,
#  ('Willie Reed', 'WAS'): -0.0,
#  ('JaKarr Sampson', 'CHO'): 1.0,
#  ('Ish Smith', 'WAS'): 1.0,
#  ('Matt Barnes', 'PHI'): -0.0,
#  ('Damjan Rudez', 'POR'): -0.0,
#  ('Jimmer Fredette', 'BRK'): 0.0,
#  ('Jeff Ayres', 'IND'): 0.0,
#  ('Meyers Leonard', 'DET'): 0.0,
#  ('Jarell Eddie', 'CHO'): 0.0,
#  ('Norris Cole', 'PHI'): 0.0,
#  ('Toney Douglas', 'IND'): 0.0,
#  ('Carmelo Anthony', 'BOS'): 0.0,
#  ('Boris Diaw', 'NOP'): -0.0,
#  ('Kawhi Leonard', 'LAC'): 0.0,
#  ('Jae Crowder', 'PHI'): 0.0,
#  ('Larry Nance Jr.', 'MIA'): 0.0,
#  ('Pau Gasol', 'MIN'): 0.0,
#  ('C.J. McCollum', 'WAS'): 0.0,
#  ('Jose Calderon', 'NYK'): 1.0,
#  ('Isaiah Canaan', 'OKC'): 0.0,
#  ('Thomas Robinson', 'LAC'): 0.0,
#  ('JaVale McGee', 'MIL'): 0.0,
#  ('Jimmer Fredette', 'LAL'): 0.0,
#  ('Walter Tavares', 'POR'): -0.0,
#  ('Corey Brewer', 'OKC'): 0.0,
#  ('Aaron Gordon', 'MIA'): 0.0,
#  ('DeMarre Carroll', 'DEN'): -0.0,
#  ('Cameron Payne', 'GSW'): 0.0,
#  ('Wesley Johnson', 'SAC'): 0.0,
#  ('Gordon Hayward', 'NYK'): 0.0,
#  ('Joe Johnson', 'PHO'): 0.0,
#  ('Russell Westbrook', 'MIA'): 0.0,
#  ('Jorge Gutierrez', 'BRK'): 0.0,
#  ('Goran Dragic', 'MIN'): 0.0,
#  ('Nazr Mohammed', 'PHO'): 0.0,
#  ('James Johnson', 'ATL'): -0.0,
#  ('Nene Hilario', 'IND'): 0.0,
#  ('Jarrett Jack', 'ORL'): 0.0,
#  ('DeAndre Jordan', 'GSW'): 0.0,
#  ('Jordan Adams', 'SAC'): 0.0,
#  ('Jordan Clarkson', 'IND'): 0.0,
#  ('Willie Reed', 'MIA'): -0.0,
#  ('Tyler Hansbrough', 'MIN'): 0.0,
#  ('Christian Wood', 'PHI'): 1.0,
#  ('Pablo Prigioni', 'PHO'): -0.0,
#  ('Pablo Prigioni', 'SAS'): 0.0,
#  ('Lucas Nogueira', 'DET'): 0.0,
#  ('Gary Neal', 'PHI'): 0.0,
#  ('T.J. Warren', 'NOP'): 0.0,
#  ('Tyson Chandler', 'TOR'): 0.0,
#  ('Christian Wood', 'HOU'): 0.0,
#  ('Andre Drummond', 'POR'): 0.0,
#  ('Alan Williams', 'DEN'): -0.0,
#  ('Andrew Bogut', 'OKC'): 0.0,
#  ('J.J. Redick', 'DAL'): 0.0,
#  ('James Young', 'IND'): -0.0,
#  ('Tyson Chandler', 'NYK'): -0.0,
#  ('J.J. Hickson', 'CHI'): 0.0,
#  ('Damien Inglis', 'ORL'): 0.0,
#  ('Tim Hardaway', 'BOS'): 0.0,
#  ('Matt Bonner', 'CHI'): 0.0,
#  ('Greg Smith', 'BOS'): -0.0,
#  ('Emmanuel Mudiay', 'CHO'): 0.0,
#  ('Nikola Mirotic', 'IND'): 0.0,
#  ('Dwyane Wade', 'MEM'): -0.0,
#  ('Darren Collison', 'SAC'): 1.0,
#  ('Gerald Henderson', 'POR'): 1.0,
#  ('Victor Oladipo', 'DEN'): 0.0,
#  ('Cleanthony Early', 'PHO'): 0.0,
#  ('Ryan Hollins', 'ATL'): 0.0,
#  ('Aaron Brooks', 'ORL'): 0.0,
#  ('Axel Toupane', 'MEM'): 0.0,
#  ('Mike Muscala', 'DEN'): 0.0,
#  ('Robert Covington', 'UTA'): 0.0,
#  ('Jerami Grant', 'BOS'): 0.0,
#  ('Kyle Singler', 'MEM'): 0.0,
#  ('Omri Casspi', 'NYK'): 0.0,
#  ('Darren Collison', 'MIL'): 0.0,
#  ('Jordan Adams', 'CLE'): 0.0,
#  ('Miles Plumlee', 'CLE'): 0.0,
#  ('Shabazz Muhammad', 'CHI'): -0.0,
#  ('Anderson Varejao', 'ATL'): 1.0,
#  ('Roy Hibbert', 'PHI'): 0.0,
#  ('Jonas Valanciunas', 'PHI'): -0.0,
#  ('Andre Drummond', 'LAL'): 0.0,
#  ('Mario Chalmers', 'SAS'): 0.0,
#  ('Mario Hezonja', 'GSW'): 0.0,
#  ('Jae Crowder', 'LAL'): 0.0,
#  ('Jimmy Butler', 'MIL'): 0.0,
#  ('Elliot Williams', 'LAL'): 0.0,
#  ('T.J. Warren', 'LAC'): 0.0,
#  ('Goran Dragic', 'POR'): 0.0,
#  ('Khris Middleton', 'IND'): 0.0,
#  ('Thabo Sefolosha', 'NYK'): 0.0,
#  ('Sasha Kaun', 'PHO'): 0.0,
#  ('Steven Adams', 'LAL'): 0.0,
#  ('Luis Montero', 'IND'): 0.0,
#  ('Mike Dunleavy', 'LAC'): 0.0,
#  ('Jordan Hamilton', 'MIL'): 0.0,
#  ('Chuck Hayes', 'MEM'): 0.0,
#  ('Ben McLemore', 'UTA'): 0.0,
#  ('Tim Hardaway', 'BRK'): 0.0,
#  ('Ray McCallum', 'LAL'): 0.0,
#  ('Jordan Farmar', 'MIL'): 0.0,
#  ('Amir Johnson', 'MIN'): 0.0,
#  ('Marcus Thornton', 'LAL'): 0.0,
#  ('Matt Bonner', 'TOR'): 0.0,
#  ('Amir Johnson', 'PHO'): 0.0,
#  ('Carl Landry', 'ORL'): -0.0,
#  ('Pat Connaughton', 'SAC'): -0.0,
#  ('Aaron Gordon', 'NYK'): 0.0,
#  ('Shaun Livingston', 'CLE'): 0.0,
#  ('Jordan Adams', 'LAC'): -0.0,
#  ('Shayne Whittington', 'CLE'): 0.0,
#  ('Nazr Mohammed', 'MEM'): 0.0,
#  ('Justin Anderson', 'NYK'): -0.0,
#  ('Jon Leuer', 'CHO'): 0.0,
#  ('Shabazz Muhammad', 'CHO'): 0.0,
#  ('Andrew Bogut', 'GSW'): 1.0,
#  ('Dwight Howard', 'HOU'): 1.0,
#  ('Kelly Olynyk', 'IND'): 0.0,
#  ('Lou Williams', 'WAS'): 0.0,
#  ('Langston Galloway', 'UTA'): 0.0,
#  ('Kelly Oubre', 'PHI'): 0.0,
#  ('Nik Stauskas', 'NYK'): 0.0,
#  ('Andre Iguodala', 'PHO'): 0.0,
#  ('Larry Nance Jr.', 'TOR'): 0.0,
#  ('Jeff Green', 'LAL'): 0.0,
#  ('Elton Brand', 'PHI'): 1.0,
#  ('Pau Gasol', 'UTA'): 0.0,
#  ('Mike Miller', 'BRK'): 0.0,
#  ('Luis Scola', 'UTA'): 0.0,
#  ('Mike Scott', 'CHI'): 0.0,
#  ('Nik Stauskas', 'WAS'): 0.0,
#  ('Anthony Brown', 'CLE'): 0.0,
#  ('Pablo Prigioni', 'DET'): 0.0,
#  ('Jimmer Fredette', 'LAC'): 0.0,
#  ('Ish Smith', 'NYK'): -0.0,
#  ('Maurice Harkless', 'NOP'): 0.0,
#  ('Anthony Brown', 'LAC'): 0.0,
#  ('Jeremy Evans', 'ATL'): 0.0,
#  ('Al-Farouq Aminu', 'BOS'): 0.0,
#  ('Ian Mahinmi', 'ORL'): 0.0,
#  ('Hassan Whiteside', 'CLE'): 0.0,
#  ('Russ Smith', 'POR'): -0.0,
#  ('Ramon Sessions', 'LAC'): 0.0,
#  ('Khris Middleton', 'OKC'): -0.0,
#  ('Nicolas Batum', 'DEN'): -0.0,
#  ('Richard Jefferson', 'TOR'): 0.0,
#  ('Ben McLemore', 'DEN'): 0.0,
#  ('Andrew Nicholson', 'BOS'): 0.0,
#  ('Chris Paul', 'BRK'): 0.0,
#  ('Langston Galloway', 'IND'): 0.0,
#  ('Carl Landry', 'PHI'): 1.0,
#  ('Tyler Zeller', 'BRK'): 0.0,
#  ('Jordan Mickey', 'PHO'): -0.0,
#  ('Nikola Mirotic', 'MEM'): 0.0,
#  ('Damian Lillard', 'PHO'): 0.0,
#  ('Andrew Bogut', 'UTA'): 0.0,
#  ('Nikola Jokic', 'SAS'): 0.0,
#  ('Alexis Ajinca', 'SAS'): -0.0,
#  ('Myles Turner', 'GSW'): 0.0,
#  ('Nikola Vucevic', 'OKC'): 0.0,
#  ('Willie Reed', 'POR'): 0.0,
#  ('Tyler Ennis', 'DEN'): 0.0,
#  ('Bobby Portis', 'PHI'): 0.0,
#  ('Evan Fournier', 'CHI'): 0.0,
#  ('DeMarre Carroll', 'MEM'): 0.0,
#  ('Chris Copeland', 'ATL'): 0.0,
#  ('Dahntay Jones', 'NOP'): 0.0,
#  ('Jamal Crawford', 'ORL'): 0.0,
#  ('Frank Kaminsky', 'MIN'): 0.0,
#  ('Ben McLemore', 'SAS'): -0.0,
#  ('Wesley Matthews', 'CLE'): 0.0,
#  ('Pau Gasol', 'SAC'): 0.0,
#  ('George Hill', 'MIN'): 0.0,
#  ('Shayne Whittington', 'BRK'): 0.0,
#  ('Rudy Gay', 'BRK'): 0.0,
#  ('Joel Anthony', 'HOU'): 0.0,
#  ('Chris Paul', 'SAC'): 0.0,
#  ('Jeff Withey', 'BRK'): 0.0,
#  ('James Michael McAdoo', 'DET'): 0.0,
#  ('Kostas Papanikolaou', 'OKC'): 0.0,
#  ('Kevin Durant', 'NYK'): 0.0,
#  ('Nene Hilario', 'DEN'): 0.0,
#  ('Tyus Jones', 'POR'): -0.0,
#  ('Patrick Beverley', 'GSW'): 0.0,
#  ('Shaun Livingston', 'WAS'): 0.0,
#  ('Jason Thompson', 'DEN'): 0.0,
#  ('Ersan Ilyasova', 'DET'): 0.0,
#  ('Chris Johnson', 'DAL'): 0.0,
#  ('Rajon Rondo', 'ORL'): 0.0,
#  ('Leandro Barbosa', 'CHI'): 0.0,
#  ('Cleanthony Early', 'MIN'): 0.0,
#  ('Damjan Rudez', 'HOU'): 0.0,
#  ('Jrue Holiday', 'LAC'): 0.0,
#  ('Sergey Karasev', 'DAL'): -0.0,
#  ('Russell Westbrook', 'TOR'): 0.0,
#  ('T.J. McConnell', 'CHO'): -0.0,
#  ('Al-Farouq Aminu', 'DEN'): -0.0,
#  ('Courtney Lee', 'WAS'): 0.0,
#  ('David Lee', 'PHO'): 0.0,
#  ('Brandon Rush', 'WAS'): 0.0,
#  ('Andrew Nicholson', 'LAL'): 0.0,
#  ('Jimmer Fredette', 'PHO'): 0.0,
#  ('Norris Cole', 'MEM'): 0.0,
#  ('Goran Dragic', 'OKC'): 0.0,
#  ('Chuck Hayes', 'SAC'): -0.0,
#  ('Chris Johnson', 'POR'): 0.0,
#  ('Carl Landry', 'TOR'): 0.0,
#  ('Tony Parker', 'IND'): 0.0,
#  ('Devyn Marble', 'ORL'): 1.0,
#  ('Joe Johnson', 'LAL'): 0.0,
#  ('Eric Moreland', 'ATL'): 0.0,
#  ('Reggie Jackson', 'LAC'): 0.0,
#  ('Monta Ellis', 'BOS'): 0.0,
#  ('Gary Neal', 'CLE'): 0.0,
#  ('Elliot Williams', 'GSW'): -0.0,
#  ('Randy Foye', 'BRK'): 0.0,
#  ('Andrea Bargnani', 'MIA'): 0.0,
#  ('Patrick Beverley', 'SAC'): 0.0,
#  ('Troy Daniels', 'ORL'): -0.0,
#  ('Mike Muscala', 'IND'): 0.0,
#  ('Harrison Barnes', 'BOS'): 0.0,
#  ('Channing Frye', 'DET'): 0.0,
#  ('Austin Rivers', 'MIA'): 0.0,
#  ('Tiago Splitter', 'GSW'): 0.0,
#  ('Shaun Livingston', 'SAS'): 0.0,
#  ('Mario Hezonja', 'WAS'): 0.0,
#  ('Matthew Dellavedova', 'DEN'): 0.0,
#  ('Axel Toupane', 'OKC'): 0.0,
#  ('Nikola Pekovic', 'MIN'): 1.0,
#  ('Greg Monroe', 'MEM'): -0.0,
#  ('Josh Huestis', 'ORL'): 0.0,
#  ('Josh McRoberts', 'DET'): 0.0,
#  ('Chris Andersen', 'GSW'): 0.0,
#  ('Jeff Ayres', 'DEN'): 0.0,
#  ('Luis Montero', 'SAC'): 0.0,
#  ('Andrew Wiggins', 'GSW'): -0.0,
#  ('Patrick Patterson', 'MIA'): 0.0,
#  ('Lucas Nogueira', 'TOR'): 1.0,
#  ('Shelvin Mack', 'UTA'): 0.0,
#  ('Drew Gooden', 'ATL'): 0.0,
#  ('Festus Ezeli', 'HOU'): 0.0,
#  ('Cole Aldrich', 'WAS'): 0.0,
#  ('DeJuan Blair', 'GSW'): -0.0,
#  ('Manu Ginobili', 'MIL'): 0.0,
#  ('Ish Smith', 'NOP'): -0.0,
#  ('Jordan Hill', 'DEN'): 0.0,
#  ('Stephen Curry', 'CHO'): 0.0,
#  ('Miles Plumlee', 'CHI'): 0.0,
#  ('Brook Lopez', 'MIA'): 0.0,
#  ('Aron Baynes', 'IND'): 0.0,
#  ('Tony Allen', 'HOU'): -0.0,
#  ('Paul George', 'MEM'): 0.0,
#  ('Dion Waiters', 'BRK'): 0.0,
#  ('Eric Bledsoe', 'HOU'): 0.0,
#  ('Derrick Williams', 'CLE'): 0.0,
#  ('Nene Hilario', 'ORL'): 0.0,
#  ('James Young', 'ATL'): 0.0,
#  ('Michael Carter-Williams', 'DET'): 0.0,
#  ('Jared Cunningham', 'IND'): 0.0,
#  ('Rudy Gobert', 'OKC'): -0.0,
#  ('Jeff Green', 'TOR'): 0.0,
#  ('Ian Mahinmi', 'TOR'): 0.0,
#  ('Sasha Kaun', 'LAL'): 0.0,
#  ('Terrence Ross', 'MIA'): 0.0,
#  ('Marcin Gortat', 'DAL'): 0.0,
#  ('Rashad Vaughn', 'SAS'): -0.0,
#  ('Jonas Valanciunas', 'TOR'): 1.0,
#  ('JaVale McGee', 'GSW'): -0.0,
#  ('Timofey Mozgov', 'ATL'): 0.0,
#  ('Bismack Biyombo', 'HOU'): 0.0,
#  ('Andrew Bogut', 'BRK'): -0.0,
#  ('Trey Lyles', 'MIL'): 0.0,
#  ('Norris Cole', 'PHO'): 0.0,
#  ('Brian Roberts', 'HOU'): 0.0,
#  ('Ryan Kelly', 'LAL'): 1.0,
#  ('Dahntay Jones', 'WAS'): -0.0,
#  ('Marcus Thornton', 'PHO'): 0.0,
#  ('Tyler Hansbrough', 'MIA'): 0.0,
#  ('Brandon Knight', 'SAS'): 0.0,
#  ('Andre Iguodala', 'IND'): 0.0,
#  ('James Young', 'CHO'): -0.0,
#  ('Kawhi Leonard', 'GSW'): 0.0,
#  ('Jeff Teague', 'HOU'): 0.0,
#  ('Markel Brown', 'PHI'): 0.0,
#  ('Nemanja Bjelica', 'MIA'): 0.0,
#  ('Lou Amundson', 'CHO'): -0.0,
#  ('Will Barton', 'MIL'): 0.0,
#  ('DeAndre Jordan', 'MIL'): 0.0,
#  ('Nik Stauskas', 'CHI'): 0.0,
#  ('Joffrey Lauvergne', 'SAC'): 0.0,
#  ('Bismack Biyombo', 'NOP'): -0.0,
#  ('Udonis Haslem', 'POR'): -0.0,
#  ('JaKarr Sampson', 'SAC'): 0.0,
#  ('Jason Smith', 'MIL'): 0.0,
#  ('C.J. Watson', 'MIA'): -0.0,
#  ('Steve Novak', 'OKC'): 0.0,
#  ('Isaiah Canaan', 'BOS'): 0.0,
#  ('Jeremy Lamb', 'LAL'): -0.0,
#  ('Julius Randle', 'CLE'): 0.0,
#  ('Lou Williams', 'ORL'): 0.0,
#  ('Cliff Alexander', 'UTA'): -0.0,
#  ('Eric Bledsoe', 'CHI'): 0.0,
#  ('Blake Griffin', 'SAC'): 0.0,
#  ('Chuck Hayes', 'POR'): 0.0,
#  ('Paul Pierce', 'IND'): 0.0,
#  ('Jeff Green', 'SAS'): 0.0,
#  ('Jeremy Lin', 'DET'): 0.0,
#  ('C.J. McCollum', 'MIN'): 0.0,
#  ('Danny Green', 'MIN'): 0.0,
#  ('Jonathon Simmons', 'OKC'): 0.0,
#  ('Alec Burks', 'CHO'): 0.0,
#  ('Justin Harper', 'LAL'): -0.0,
#  ('Mario Hezonja', 'TOR'): -0.0,
#  ('Tyson Chandler', 'CHI'): 0.0,
#  ('Michael Kidd-Gilchrist', 'MEM'): -0.0,
#  ('Richard Jefferson', 'WAS'): 0.0,
#  ('DeMar DeRozan', 'SAS'): 0.0,
#  ('Kelly Oubre', 'TOR'): 0.0,
#  ('Karl-Anthony Towns', 'MIA'): 0.0,
#  ('Andre Miller', 'ATL'): 0.0,
#  ('Dwight Powell', 'LAC'): 0.0,
#  ('Darrell Arthur', 'SAC'): 0.0,
#  ('Frank Kaminsky', 'ORL'): 0.0,
#  ('Thanasis Antetokounmpo', 'WAS'): 0.0,
#  ('Sergey Karasev', 'OKC'): 0.0,
#  ('DeMarcus Cousins', 'PHO'): 0.0,
#  ('Mitch McGary', 'SAS'): 0.0,
#  ('Shelvin Mack', 'DET'): 0.0,
#  ('Jordan Mickey', 'LAL'): 0.0,
#  ('Reggie Jackson', 'DAL'): 0.0,
#  ('David Lee', 'MIN'): 1.0,
#  ('Cory Jefferson', 'BOS'): 0.0,
#  ('Austin Rivers', 'NYK'): 0.0,
#  ('Rondae Hollis-Jefferson', 'MIA'): 0.0,
#  ('JaVale McGee', 'ATL'): 0.0,
#  ('Nick Collison', 'CHO'): 0.0,
#  ('Evan Turner', 'POR'): 0.0,
#  ('Rondae Hollis-Jefferson', 'SAC'): 0.0,
#  ('Chase Budinger', 'UTA'): 0.0,
#  ('Erick Green', 'SAS'): -0.0,
#  ('J.J. Hickson', 'LAC'): 0.0,
#  ('Gary Neal', 'PHO'): 0.0,
#  ('Caron Butler', 'BOS'): 0.0,
#  ('Roy Hibbert', 'DEN'): 0.0,
#  ('Garrett Temple', 'POR'): 0.0,
#  ('Michael Carter-Williams', 'GSW'): 0.0,
#  ('C.J. Wilcox', 'MIA'): -0.0,
#  ('Anthony Tolliver', 'MIN'): -0.0,
#  ('Damien Inglis', 'TOR'): 0.0,
#  ('Rashad Vaughn', 'LAC'): 0.0,
#  ('Elton Brand', 'ATL'): 0.0,
#  ('Andrew Bogut', 'MIL'): 0.0,
#  ('Kyrie Irving', 'MIN'): -0.0,
#  ('Zach LaVine', 'MIL'): 0.0,
#  ('Ian Clark', 'DEN'): 0.0,
#  ('Robert Sacre', 'WAS'): 0.0,
#  ('Avery Bradley', 'NOP'): 0.0,
#  ('Tarik Black', 'HOU'): 0.0,
#  ('Rashad Vaughn', 'MIL'): 1.0,
#  ('Joe Johnson', 'HOU'): 0.0,
#  ('Justise Winslow', 'BRK'): 0.0,
#  ('Jose Calderon', 'CHI'): 0.0,
#  ('Boban Marjanovic', 'IND'): 0.0,
#  ('Nick Young', 'MIL'): 0.0,
#  ('James Ennis', 'SAC'): 0.0,
#  ('Hassan Whiteside', 'NOP'): 0.0,
#  ('Sasha Vujacic', 'NYK'): 1.0,
#  ('Noah Vonleh', 'NYK'): 0.0,
#  ('Thanasis Antetokounmpo', 'NYK'): 1.0,
#  ('Andre Miller', 'PHO'): 0.0,
#  ('Devyn Marble', 'SAC'): 0.0,
#  ('Duje Dukan', 'IND'): -0.0,
#  ('Kyle Korver', 'MIA'): 0.0,
#  ('Nik Stauskas', 'MIL'): 0.0,
#  ('Serge Ibaka', 'GSW'): 0.0,
#  ('Nicolas Batum', 'BRK'): 0.0,
#  ('Jon Leuer', 'IND'): 0.0,
#  ('Steven Adams', 'PHI'): 0.0,
#  ('Lou Williams', 'GSW'): 0.0,
#  ('Joel Anthony', 'OKC'): -0.0,
#  ('Dirk Nowitzki', 'IND'): 0.0,
#  ('Kevin Seraphin', 'LAL'): 0.0,
#  ('Quincy Acy', 'SAC'): 1.0,
#  ('Chris McCullough', 'MEM'): 0.0,
#  ('Kevin Durant', 'MIA'): 0.0,
#  ('Robin Lopez', 'WAS'): 0.0,
#  ('Terrence Ross', 'POR'): 0.0,
#  ('Draymond Green', 'CHO'): 0.0,
#  ('Jae Crowder', 'HOU'): 0.0,
#  ('Steven Adams', 'WAS'): -0.0,
#  ('Spencer Hawes', 'MIA'): 0.0,
#  ('Elliot Williams', 'CLE'): -0.0,
#  ('Jared Dudley', 'UTA'): 0.0,
#  ('DeMarre Carroll', 'LAC'): 0.0,
#  ("E'Twaun Moore", 'SAS'): 0.0,
#  ('Steve Novak', 'NOP'): 0.0,
#  ('Kyle Singler', 'CHO'): 0.0,
#  ('DeMarre Carroll', 'PHI'): 0.0,
#  ('Evan Turner', 'DET'): 0.0,
#  ('Mason Plumlee', 'LAL'): 0.0,
#  ('Thabo Sefolosha', 'OKC'): -0.0,
#  ('Jared Sullinger', 'SAC'): 0.0,
#  ('James Johnson', 'DET'): 0.0,
#  ('Luis Scola', 'LAC'): 0.0,
#  ('Dion Waiters', 'BOS'): -0.0,
#  ('James Anderson', 'MEM'): 0.0,
#  ('Jason Thompson', 'SAS'): 0.0,
#  ('JaVale McGee', 'SAS'): -0.0,
#  ('Tobias Harris', 'LAC'): 0.0,
#  ('Richaun Holmes', 'CLE'): 0.0,
#  ('Mike Scott', 'SAS'): 0.0,
#  ('Tyler Hansbrough', 'CHI'): 0.0,
#  ('Jason Terry', 'SAC'): -0.0,
#  ('C.J. Watson', 'POR'): 0.0,
#  ...}

# %%
min_team_rating
#sol_min_team_rating = m.getAttr('X',min_team_rating)
#sol_min_team_rating
# Out:
# <gurobi.Var minimum_team_rating (value 0.0017648010645105842)>

# %%
max_team_rating
# Out:
# <gurobi.Var maximum_team_rating (value 0.0027648010645105843)>

# %%
sol_player_assignment = {}
for k,v in sol_player_assigned_to_team.items():
    if sol_player_assigned_to_team[k[0],k[1]] == 1:
        sol_player_assignment[k[0]] = k[1]
        print(k[0]+" : "+k[1])
# Out:
# James Young : BOS
# Austin Rivers : LAC
# Lou Amundson : NYK
# Justin Holiday : BOS
# Ty Lawson : CHI
# Blake Griffin : LAC
# Damian Lillard : POR
# Kyle Lowry : TOR
# Nikola Mirotic : CHI
# Greivis Vasquez : MIL
# Rasual Butler : SAS
# Leandro Barbosa : GSW
# Norman Powell : TOR
# Steve Blake : DET
# Russ Smith : MEM
# Jared Sullinger : BOS
# Walter Tavares : ATL
# Jeremy Evans : DAL
# Amar'e Stoudemire : MIA
# JaKarr Sampson : CHO
# Ish Smith : WAS
# Jose Calderon : NYK
# Christian Wood : PHI
# Darren Collison : SAC
# Gerald Henderson : POR
# Anderson Varejao : ATL
# Andrew Bogut : GSW
# Dwight Howard : HOU
# Elton Brand : PHI
# Carl Landry : PHI
# Devyn Marble : ORL
# Nikola Pekovic : MIN
# Lucas Nogueira : TOR
# Jonas Valanciunas : TOR
# Ryan Kelly : LAL
# David Lee : MIN
# Rashad Vaughn : MIL
# Sasha Vujacic : NYK
# Thanasis Antetokounmpo : NYK
# Quincy Acy : SAC
# Mike Scott : ATL
# Duje Dukan : SAC
# Jared Cunningham : CHO
# Jodie Meeks : DET
# Greg Monroe : MIL
# Michael Kidd-Gilchrist : CHO
# Glenn Robinson : IND
# Victor Oladipo : ORL
# Joseph Young : IND
# Hollis Thompson : PHI
# Marc Gasol : MEM
# Chris McCullough : BRK
# Kyle O'Quinn : NYK
# Andrew Nicholson : ORL
# Raul Neto : UTA
# Aaron Harrison : CHO
# J.J. Redick : LAC
# Ryan Anderson : NOP
# Andre Miller : LAC
# Zach LaVine : MIN
# Chris Kaman : POR
# Allen Crabbe : POR
# Terrence Ross : TOR
# Taj Gibson : CHI
# Maurice Harkless : POR
# Rodney Hood : UTA
# Ray McCallum : CHO
# Jeff Ayres : LAC
# Tibor Pleiss : UTA
# Josh Smith : BRK
# Rakeem Christmas : IND
# Tobias Harris : MEM
# Corey Brewer : HOU
# Alexis Ajinca : NOP
# Danilo Gallinari : DEN
# Roy Hibbert : LAL
# Jeremy Lin : CHO
# Derrick Rose : CHI
# P.J. Tucker : PHO
# Kendrick Perkins : NOP
# Jarnell Stokes : GSW
# Shabazz Napier : ORL
# Tayshaun Prince : MIN
# Kobe Bryant : LAL
# Alonzo Gee : NOP
# Anthony Tolliver : DET
# Dwight Powell : DAL
# Marcus Morris : DET
# Raymond Felton : DAL
# Marcus Thornton : IND
# Joe Johnson : ORL
# James Michael McAdoo : GSW
# Jarrett Jack : BRK
# Al-Farouq Aminu : POR
# Rodney Stuckey : IND
# Draymond Green : GSW
# Joakim Noah : CHI
# Tony Parker : SAS
# Jonathon Simmons : SAS
# Tony Snell : CHI
# C.J. McCollum : POR
# Solomon Hill : IND
# J.R. Smith : CLE
# Omer Asik : NOP
# Shane Larkin : BRK
# Dwyane Wade : MIA
# Kevin Garnett : MIN
# Richaun Holmes : PHI
# Arron Afflalo : NYK
# Luke Babbitt : NOP
# DeMarre Carroll : TOR
# Anthony Brown : LAL
# Clint Capela : HOU
# J.J. Barea : DAL
# Kevin Martin : CLE
# Marvin Williams : CHO
# Elijah Millsap : UTA
# Ricky Rubio : MIN
# Robert Sacre : LAL
# Dennis Schroder : ATL
# Rudy Gobert : UTA
# James Ennis : MIL
# Deron Williams : DAL
# Kostas Papanikolaou : DEN
# Marreese Speights : GSW
# Jordan Clarkson : LAL
# Brook Lopez : BRK
# George Hill : IND
# Marco Belinelli : SAC
# Bismack Biyombo : TOR
# Jamal Crawford : LAC
# Aaron Gordon : ORL
# Tony Allen : MEM
# Al Jefferson : CHO
# Jared Dudley : WAS
# Matt Barnes : MEM
# DeJuan Blair : WAS
# Klay Thompson : GSW
# Larry Nance Jr. : LAL
# Shabazz Muhammad : MIN
# C.J. Miles : IND
# Justin Harper : DET
# Wayne Ellington : BRK
# Mike Muscala : ATL
# Jahlil Okafor : PHI
# Eric Bledsoe : PHO
# Cristiano Felicio : CHI
# Lou Williams : LAL
# Kevon Looney : GSW
# Trey Burke : UTA
# Marcin Gortat : WAS
# Andrew Goudelock : HOU
# Dion Waiters : OKC
# Ryan Hollins : MEM
# Anthony Bennett : TOR
# Terrence Jones : HOU
# Jameer Nelson : DEN
# Jeff Green : MEM
# Kentavious Caldwell-Pope : DET
# Lorenzo Brown : PHO
# Giannis Antetokounmpo : MIL
# Tim Hardaway : ATL
# Kris Humphries : SAS
# Jeremy Lamb : CHO
# Paul Pierce : LAC
# J.J. Hickson : SAS
# Avery Bradley : BOS
# Trevor Ariza : HOU
# Johnny O'Bryant : MIL
# Coty Clarke : BOS
# Will Barton : DEN
# Pat Connaughton : POR
# Zach Randolph : MEM
# Tyler Hansbrough : CHO
# John Wall : WAS
# Chris Andersen : NYK
# Steven Adams : OKC
# Dahntay Jones : CLE
# Bojan Bogdanovic : BRK
# E'Twaun Moore : CHI
# Josh McRoberts : MIA
# Derrick Williams : NYK
# Anthony Davis : NOP
# DeAndre Jordan : LAC
# T.J. McConnell : PHI
# Jusuf Nurkic : DEN
# Jarell Martin : MEM
# Robert Covington : PHI
# Zaza Pachulia : DAL
# Devin Booker : PHO
# Joffrey Lauvergne : DEN
# LaMarcus Aldridge : SAS
# R.J. Hunter : BOS
# Markel Brown : BRK
# Garrett Temple : WAS
# Myles Turner : IND
# Cliff Alexander : POR
# D.J. Augustin : WAS
# Mario Hezonja : ORL
# Darrun Hilliard : DET
# Andrew Wiggins : MIN
# Devin Harris : DAL
# Jason Thompson : ORL
# Miles Plumlee : MIL
# Elliot Williams : MEM
# Tyreke Evans : NOP
# Reggie Jackson : DET
# Cameron Bairstow : CHI
# Thomas Robinson : BRK
# Gorgui Dieng : MIN
# Reggie Bullock : DET
# JaVale McGee : DAL
# Jorge Gutierrez : CHO
# Tarik Black : LAL
# Nick Collison : OKC
# Stanley Johnson : DET
# LeBron James : PHI
# Alan Williams : PHO
# Emmanuel Mudiay : DEN
# Branden Dawson : LAC
# Donald Sloan : BRK
# Andre Drummond : DET
# Tyler Zeller : BOS
# DeMar DeRozan : TOR
# James Johnson : TOR
# Matthew Dellavedova : CLE
# Pablo Prigioni : LAC
# Serge Ibaka : OKC
# Isaiah Canaan : PHI
# Rajon Rondo : SAC
# Tim Duncan : SAS
# Luis Montero : SAS
# Langston Galloway : NYK
# Aaron Brooks : CHI
# Jordan McRae : SAC
# Chris Bosh : MIA
# Stephen Curry : LAL
# Chris Johnson : UTA
# Donatas Motiejunas : HOU
# Evan Fournier : ORL
# Gerald Green : CHI
# Phil Pressey : DET
# Henry Sims : BRK
# Eric Moreland : SAC
# Monta Ellis : IND
# Hassan Whiteside : MIA
# Jon Leuer : PHO
# Tim Frazier : DEN
# Cory Jefferson : IND
# Courtney Lee : MIN
# David West : SAS
# Briante Weber : POR
# Ronnie Price : PHO
# Troy Daniels : CHO
# John Jenkins : POR
# Tristan Thompson : CLE
# Jordan Farmar : MEM
# Joe Ingles : UTA
# Lance Thomas : NYK
# Ed Davis : POR
# Darrell Arthur : DEN
# Cameron Payne : OKC
# Chris Paul : LAL
# Beno Udrih : CLE
# Robin Lopez : NYK
# Tyler Johnson : MIA
# Toney Douglas : NOP
# Luc Mbah a Moute : LAC
# Cole Aldrich : LAC
# Chase Budinger : WAS
# Kendall Marshall : PHI
# Patrick Beverley : HOU
# Kelly Oubre : WAS
# Khris Middleton : MIL
# Jarell Eddie : WAS
# Damien Inglis : MIL
# Jonas Jerebko : BOS
# Kevin Seraphin : NYK
# Rondae Hollis-Jefferson : BRK
# Jabari Parker : MIL
# Markieff Morris : SAC
# Bryce Dejean-Jones : NOP
# Bruno Caboclo : TOR
# Marcus Smart : BOS
# Lamar Patterson : ATL
# Patrick Patterson : TOR
# Delon Wright : TOR
# Vince Carter : MEM
# C.J. Wilcox : LAC
# Trevor Booker : UTA
# Gary Neal : WAS
# Jason Terry : HOU
# Willie Reed : BRK
# Tyler Ennis : LAC
# Randy Foye : CLE
# Justise Winslow : MIA
# Alan Anderson : WAS
# Andre Roberson : OKC
# Pau Gasol : CHI
# James Jones : CLE
# Gordon Hayward : UTA
# Patrick Mills : SAS
# Xavier Munford : MEM
# Goran Dragic : MIA
# Richard Jefferson : CLE
# Terry Rozier : BOS
# Damjan Rudez : MIN
# Montrezl Harrell : HOU
# Ramon Sessions : WAS
# Ian Clark : GSW
# Sasha Kaun : CLE
# Orlando Johnson : LAC
# Kent Bazemore : ATL
# Bobby Portis : CHI
# Ersan Ilyasova : PHI
# Trey Lyles : UTA
# Drew Gooden : WAS
# Nate Robinson : ATL
# Shaun Livingston : GSW
# Chandler Parsons : DAL
# Mike Conley : MEM
# D'Angelo Russell : LAL
# Kristaps Porzingis : NYK
# Derrick Favors : UTA
# Nene Hilario : WAS
# Thabo Sefolosha : ATL
# Brandon Bass : LAL
# James Harden : HOU
# Iman Shumpert : CLE
# J.J. O'Brien : UTA
# Chuck Hayes : HOU
# Metta World Peace : LAL
# Noah Vonleh : POR
# Ben McLemore : SAC
# Jeff Teague : ATL
# Paul George : IND
# Cody Zeller : CHO
# Norris Cole : NOP
# Kenneth Faried : DEN
# Michael Carter-Williams : MIL
# Thaddeus Young : BRK
# Lance Stephenson : OKC
# Willie Cauley-Stein : SAC
# Caron Butler : SAC
# C.J. Watson : ORL
# Alex Stepheson : OKC
# Enes Kanter : OKC
# Russell Westbrook : MIL
# Kyle Anderson : SAS
# Seth Curry : SAC
# Josh Richardson : MIA
# Danny Green : SAS
# Kawhi Leonard : BRK
# Mason Plumlee : POR
# Jimmy Butler : CHI
# Jordan Hill : IND
# Mirza Teletovic : PHO
# Nemanja Bjelica : MIN
# Mitch McGary : OKC
# Kevin Love : CLE
# Mario Chalmers : MIN
# Anthony Morrow : OKC
# Jerryd Bayless : MIL
# Harrison Barnes : GSW
# Ian Mahinmi : IND
# Mo Williams : CLE
# Alex Len : PHO
# Cleanthony Early : TOR
# John Henson : MIL
# P.J. Hairston : MIA
# Brandon Jennings : OKC
# Marcelo Huertas : LAL
# Adreian Payne : MIN
# Evan Turner : BOS
# K.J. McDaniels : HOU
# Chris Copeland : MIL
# Jeff Withey : UTA
# Bryce Cotton : MIA
# Timofey Mozgov : CLE
# Julius Randle : LAL
# Kemba Walker : CHO
# Lavoy Allen : IND
# Nerlens Noel : PHI
# Keith Appling : GSW
# Frank Kaminsky : CHO
# Meyers Leonard : POR
# Dewayne Dedmon : ORL
# Jordan Adams : MEM
# Axel Toupane : DEN
# Udonis Haslem : MIA
# Jerami Grant : PHI
# Tiago Splitter : ATL
# Elfrid Payton : ORL
# Brandan Wright : MEM
# Shelvin Mack : PHI
# Matt Bonner : SAS
# Erick Green : OKC
# Jordan Mickey : BOS
# Andre Iguodala : GSW
# JaMychal Green : MEM
# Paul Millsap : ATL
# Jordan Hamilton : NOP
# T.J. Warren : PHO
# Spencer Dinwiddie : DET
# Tyson Chandler : PHO
# Alec Burks : UTA
# Luol Deng : MIA
# Eric Gordon : NOP
# Kevin Durant : OKC
# Steve Novak : DAL
# Archie Goodwin : PHO
# Isaiah Thomas : BOS
# Kyrie Irving : CLE
# Greg Smith : MIN
# Joel Anthony : DET
# Nicolas Batum : CHO
# Sergey Karasev : BRK
# Doug McDermott : CHI
# Justin Anderson : DAL
# Andrea Bargnani : BRK
# Mike Dunleavy : CHI
# Spencer Hawes : CHO
# Kyle Singler : OKC
# Omri Casspi : SAC
# Kirk Hinrich : CLE
# Sam Dekker : HOU
# Kosta Koufos : SAC
# Al Horford : ATL
# Bradley Beal : WAS
# Brandon Knight : PHO
# O.J. Mayo : MIL
# Wesley Matthews : DAL
# Shayne Whittington : IND
# Brandon Rush : GSW
# Jimmer Fredette : DAL
# Karl-Anthony Towns : MIN
# Boris Diaw : SAS
# Jae Crowder : BOS
# Nikola Jokic : DEN
# James Anderson : SAC
# DeMarcus Cousins : SAC
# Aron Baynes : DET
# Kelly Olynyk : BOS
# Luis Scola : TOR
# Joe Harris : CLE
# Jason Smith : ORL
# Sean Kilpatrick : DAL
# Nazr Mohammed : SAS
# Michael Beasley : HOU
# Brian Roberts : TOR
# Nik Stauskas : PHI
# Jrue Holiday : NOP
# Tony Wroten : UTA
# Charlie Villanueva : DAL
# Otto Porter : WAS
# Kyle Korver : ATL
# Nikola Vucevic : ORL
# Sonny Weems : BOS
# Cory Joseph : TOR
# Mike Miller : DEN
# Nick Young : LAL
# Salah Mejri : DAL
# Carmelo Anthony : NYK
# Jerian Grant : NYK
# Amir Johnson : BOS
# Boban Marjanovic : SAS
# Rudy Gay : SAC
# Channing Frye : PHI
# Dante Cunningham : NOP
# Manu Ginobili : SAS
# Gary Harris : DEN
# Wesley Johnson : LAC
# Josh Huestis : OKC
# Festus Ezeli : GSW
# Dirk Nowitzki : DAL
# Tyus Jones : MIN

# %%
sol_player_assignment
# Out:
# {'Aaron Brooks': 'CHI',
#  'Aaron Gordon': 'ORL',
#  'Aaron Harrison': 'CHO',
#  'Adreian Payne': 'MIN',
#  'Al Horford': 'ATL',
#  'Al Jefferson': 'CHO',
#  'Al-Farouq Aminu': 'POR',
#  'Alan Anderson': 'WAS',
#  'Alan Williams': 'PHO',
#  'Alec Burks': 'UTA',
#  'Alex Len': 'PHO',
#  'Alex Stepheson': 'OKC',
#  'Alexis Ajinca': 'NOP',
#  'Allen Crabbe': 'POR',
#  'Alonzo Gee': 'NOP',
#  "Amar'e Stoudemire": 'MIA',
#  'Amir Johnson': 'BOS',
#  'Anderson Varejao': 'ATL',
#  'Andre Drummond': 'DET',
#  'Andre Iguodala': 'GSW',
#  'Andre Miller': 'LAC',
#  'Andre Roberson': 'OKC',
#  'Andrea Bargnani': 'BRK',
#  'Andrew Bogut': 'GSW',
#  'Andrew Goudelock': 'HOU',
#  'Andrew Nicholson': 'ORL',
#  'Andrew Wiggins': 'MIN',
#  'Anthony Bennett': 'TOR',
#  'Anthony Brown': 'LAL',
#  'Anthony Davis': 'NOP',
#  'Anthony Morrow': 'OKC',
#  'Anthony Tolliver': 'DET',
#  'Archie Goodwin': 'PHO',
#  'Aron Baynes': 'DET',
#  'Arron Afflalo': 'NYK',
#  'Austin Rivers': 'LAC',
#  'Avery Bradley': 'BOS',
#  'Axel Toupane': 'DEN',
#  'Ben McLemore': 'SAC',
#  'Beno Udrih': 'CLE',
#  'Bismack Biyombo': 'TOR',
#  'Blake Griffin': 'LAC',
#  'Boban Marjanovic': 'SAS',
#  'Bobby Portis': 'CHI',
#  'Bojan Bogdanovic': 'BRK',
#  'Boris Diaw': 'SAS',
#  'Bradley Beal': 'WAS',
#  'Brandan Wright': 'MEM',
#  'Branden Dawson': 'LAC',
#  'Brandon Bass': 'LAL',
#  'Brandon Jennings': 'OKC',
#  'Brandon Knight': 'PHO',
#  'Brandon Rush': 'GSW',
#  'Brian Roberts': 'TOR',
#  'Briante Weber': 'POR',
#  'Brook Lopez': 'BRK',
#  'Bruno Caboclo': 'TOR',
#  'Bryce Cotton': 'MIA',
#  'Bryce Dejean-Jones': 'NOP',
#  'C.J. McCollum': 'POR',
#  'C.J. Miles': 'IND',
#  'C.J. Watson': 'ORL',
#  'C.J. Wilcox': 'LAC',
#  'Cameron Bairstow': 'CHI',
#  'Cameron Payne': 'OKC',
#  'Carl Landry': 'PHI',
#  'Carmelo Anthony': 'NYK',
#  'Caron Butler': 'SAC',
#  'Chandler Parsons': 'DAL',
#  'Channing Frye': 'PHI',
#  'Charlie Villanueva': 'DAL',
#  'Chase Budinger': 'WAS',
#  'Chris Andersen': 'NYK',
#  'Chris Bosh': 'MIA',
#  'Chris Copeland': 'MIL',
#  'Chris Johnson': 'UTA',
#  'Chris Kaman': 'POR',
#  'Chris McCullough': 'BRK',
#  'Chris Paul': 'LAL',
#  'Christian Wood': 'PHI',
#  'Chuck Hayes': 'HOU',
#  'Cleanthony Early': 'TOR',
#  'Cliff Alexander': 'POR',
#  'Clint Capela': 'HOU',
#  'Cody Zeller': 'CHO',
#  'Cole Aldrich': 'LAC',
#  'Corey Brewer': 'HOU',
#  'Cory Jefferson': 'IND',
#  'Cory Joseph': 'TOR',
#  'Coty Clarke': 'BOS',
#  'Courtney Lee': 'MIN',
#  'Cristiano Felicio': 'CHI',
#  "D'Angelo Russell": 'LAL',
#  'D.J. Augustin': 'WAS',
#  'Dahntay Jones': 'CLE',
#  'Damian Lillard': 'POR',
#  'Damien Inglis': 'MIL',
#  'Damjan Rudez': 'MIN',
#  'Danilo Gallinari': 'DEN',
#  'Danny Green': 'SAS',
#  'Dante Cunningham': 'NOP',
#  'Darrell Arthur': 'DEN',
#  'Darren Collison': 'SAC',
#  'Darrun Hilliard': 'DET',
#  'David Lee': 'MIN',
#  'David West': 'SAS',
#  'DeAndre Jordan': 'LAC',
#  'DeJuan Blair': 'WAS',
#  'DeMar DeRozan': 'TOR',
#  'DeMarcus Cousins': 'SAC',
#  'DeMarre Carroll': 'TOR',
#  'Delon Wright': 'TOR',
#  'Dennis Schroder': 'ATL',
#  'Deron Williams': 'DAL',
#  'Derrick Favors': 'UTA',
#  'Derrick Rose': 'CHI',
#  'Derrick Williams': 'NYK',
#  'Devin Booker': 'PHO',
#  'Devin Harris': 'DAL',
#  'Devyn Marble': 'ORL',
#  'Dewayne Dedmon': 'ORL',
#  'Dion Waiters': 'OKC',
#  'Dirk Nowitzki': 'DAL',
#  'Donald Sloan': 'BRK',
#  'Donatas Motiejunas': 'HOU',
#  'Doug McDermott': 'CHI',
#  'Draymond Green': 'GSW',
#  'Drew Gooden': 'WAS',
#  'Duje Dukan': 'SAC',
#  'Dwight Howard': 'HOU',
#  'Dwight Powell': 'DAL',
#  'Dwyane Wade': 'MIA',
#  "E'Twaun Moore": 'CHI',
#  'Ed Davis': 'POR',
#  'Elfrid Payton': 'ORL',
#  'Elijah Millsap': 'UTA',
#  'Elliot Williams': 'MEM',
#  'Elton Brand': 'PHI',
#  'Emmanuel Mudiay': 'DEN',
#  'Enes Kanter': 'OKC',
#  'Eric Bledsoe': 'PHO',
#  'Eric Gordon': 'NOP',
#  'Eric Moreland': 'SAC',
#  'Erick Green': 'OKC',
#  'Ersan Ilyasova': 'PHI',
#  'Evan Fournier': 'ORL',
#  'Evan Turner': 'BOS',
#  'Festus Ezeli': 'GSW',
#  'Frank Kaminsky': 'CHO',
#  'Garrett Temple': 'WAS',
#  'Gary Harris': 'DEN',
#  'Gary Neal': 'WAS',
#  'George Hill': 'IND',
#  'Gerald Green': 'CHI',
#  'Gerald Henderson': 'POR',
#  'Giannis Antetokounmpo': 'MIL',
#  'Glenn Robinson': 'IND',
#  'Goran Dragic': 'MIA',
#  'Gordon Hayward': 'UTA',
#  'Gorgui Dieng': 'MIN',
#  'Greg Monroe': 'MIL',
#  'Greg Smith': 'MIN',
#  'Greivis Vasquez': 'MIL',
#  'Harrison Barnes': 'GSW',
#  'Hassan Whiteside': 'MIA',
#  'Henry Sims': 'BRK',
#  'Hollis Thompson': 'PHI',
#  'Ian Clark': 'GSW',
#  'Ian Mahinmi': 'IND',
#  'Iman Shumpert': 'CLE',
#  'Isaiah Canaan': 'PHI',
#  'Isaiah Thomas': 'BOS',
#  'Ish Smith': 'WAS',
#  'J.J. Barea': 'DAL',
#  'J.J. Hickson': 'SAS',
#  "J.J. O'Brien": 'UTA',
#  'J.J. Redick': 'LAC',
#  'J.R. Smith': 'CLE',
#  'JaKarr Sampson': 'CHO',
#  'JaMychal Green': 'MEM',
#  'JaVale McGee': 'DAL',
#  'Jabari Parker': 'MIL',
#  'Jae Crowder': 'BOS',
#  'Jahlil Okafor': 'PHI',
#  'Jamal Crawford': 'LAC',
#  'Jameer Nelson': 'DEN',
#  'James Anderson': 'SAC',
#  'James Ennis': 'MIL',
#  'James Harden': 'HOU',
#  'James Johnson': 'TOR',
#  'James Jones': 'CLE',
#  'James Michael McAdoo': 'GSW',
#  'James Young': 'BOS',
#  'Jared Cunningham': 'CHO',
#  'Jared Dudley': 'WAS',
#  'Jared Sullinger': 'BOS',
#  'Jarell Eddie': 'WAS',
#  'Jarell Martin': 'MEM',
#  'Jarnell Stokes': 'GSW',
#  'Jarrett Jack': 'BRK',
#  'Jason Smith': 'ORL',
#  'Jason Terry': 'HOU',
#  'Jason Thompson': 'ORL',
#  'Jeff Ayres': 'LAC',
#  'Jeff Green': 'MEM',
#  'Jeff Teague': 'ATL',
#  'Jeff Withey': 'UTA',
#  'Jerami Grant': 'PHI',
#  'Jeremy Evans': 'DAL',
#  'Jeremy Lamb': 'CHO',
#  'Jeremy Lin': 'CHO',
#  'Jerian Grant': 'NYK',
#  'Jerryd Bayless': 'MIL',
#  'Jimmer Fredette': 'DAL',
#  'Jimmy Butler': 'CHI',
#  'Joakim Noah': 'CHI',
#  'Jodie Meeks': 'DET',
#  'Joe Harris': 'CLE',
#  'Joe Ingles': 'UTA',
#  'Joe Johnson': 'ORL',
#  'Joel Anthony': 'DET',
#  'Joffrey Lauvergne': 'DEN',
#  'John Henson': 'MIL',
#  'John Jenkins': 'POR',
#  'John Wall': 'WAS',
#  "Johnny O'Bryant": 'MIL',
#  'Jon Leuer': 'PHO',
#  'Jonas Jerebko': 'BOS',
#  'Jonas Valanciunas': 'TOR',
#  'Jonathon Simmons': 'SAS',
#  'Jordan Adams': 'MEM',
#  'Jordan Clarkson': 'LAL',
#  'Jordan Farmar': 'MEM',
#  'Jordan Hamilton': 'NOP',
#  'Jordan Hill': 'IND',
#  'Jordan McRae': 'SAC',
#  'Jordan Mickey': 'BOS',
#  'Jorge Gutierrez': 'CHO',
#  'Jose Calderon': 'NYK',
#  'Joseph Young': 'IND',
#  'Josh Huestis': 'OKC',
#  'Josh McRoberts': 'MIA',
#  'Josh Richardson': 'MIA',
#  'Josh Smith': 'BRK',
#  'Jrue Holiday': 'NOP',
#  'Julius Randle': 'LAL',
#  'Justin Anderson': 'DAL',
#  'Justin Harper': 'DET',
#  'Justin Holiday': 'BOS',
#  'Justise Winslow': 'MIA',
#  'Jusuf Nurkic': 'DEN',
#  'K.J. McDaniels': 'HOU',
#  'Karl-Anthony Towns': 'MIN',
#  'Kawhi Leonard': 'BRK',
#  'Keith Appling': 'GSW',
#  'Kelly Olynyk': 'BOS',
#  'Kelly Oubre': 'WAS',
#  'Kemba Walker': 'CHO',
#  'Kendall Marshall': 'PHI',
#  'Kendrick Perkins': 'NOP',
#  'Kenneth Faried': 'DEN',
#  'Kent Bazemore': 'ATL',
#  'Kentavious Caldwell-Pope': 'DET',
#  'Kevin Durant': 'OKC',
#  'Kevin Garnett': 'MIN',
#  'Kevin Love': 'CLE',
#  'Kevin Martin': 'CLE',
#  'Kevin Seraphin': 'NYK',
#  'Kevon Looney': 'GSW',
#  'Khris Middleton': 'MIL',
#  'Kirk Hinrich': 'CLE',
#  'Klay Thompson': 'GSW',
#  'Kobe Bryant': 'LAL',
#  'Kosta Koufos': 'SAC',
#  'Kostas Papanikolaou': 'DEN',
#  'Kris Humphries': 'SAS',
#  'Kristaps Porzingis': 'NYK',
#  'Kyle Anderson': 'SAS',
#  'Kyle Korver': 'ATL',
#  'Kyle Lowry': 'TOR',
#  "Kyle O'Quinn": 'NYK',
#  'Kyle Singler': 'OKC',
#  'Kyrie Irving': 'CLE',
#  'LaMarcus Aldridge': 'SAS',
#  'Lamar Patterson': 'ATL',
#  'Lance Stephenson': 'OKC',
#  'Lance Thomas': 'NYK',
#  'Langston Galloway': 'NYK',
#  'Larry Nance Jr.': 'LAL',
#  'Lavoy Allen': 'IND',
#  'LeBron James': 'PHI',
#  'Leandro Barbosa': 'GSW',
#  'Lorenzo Brown': 'PHO',
#  'Lou Amundson': 'NYK',
#  'Lou Williams': 'LAL',
#  'Luc Mbah a Moute': 'LAC',
#  'Lucas Nogueira': 'TOR',
#  'Luis Montero': 'SAS',
#  'Luis Scola': 'TOR',
#  'Luke Babbitt': 'NOP',
#  'Luol Deng': 'MIA',
#  'Manu Ginobili': 'SAS',
#  'Marc Gasol': 'MEM',
#  'Marcelo Huertas': 'LAL',
#  'Marcin Gortat': 'WAS',
#  'Marco Belinelli': 'SAC',
#  'Marcus Morris': 'DET',
#  'Marcus Smart': 'BOS',
#  'Marcus Thornton': 'IND',
#  'Mario Chalmers': 'MIN',
#  'Mario Hezonja': 'ORL',
#  'Markel Brown': 'BRK',
#  'Markieff Morris': 'SAC',
#  'Marreese Speights': 'GSW',
#  'Marvin Williams': 'CHO',
#  'Mason Plumlee': 'POR',
#  'Matt Barnes': 'MEM',
#  'Matt Bonner': 'SAS',
#  'Matthew Dellavedova': 'CLE',
#  'Maurice Harkless': 'POR',
#  'Metta World Peace': 'LAL',
#  'Meyers Leonard': 'POR',
#  'Michael Beasley': 'HOU',
#  'Michael Carter-Williams': 'MIL',
#  'Michael Kidd-Gilchrist': 'CHO',
#  'Mike Conley': 'MEM',
#  'Mike Dunleavy': 'CHI',
#  'Mike Miller': 'DEN',
#  'Mike Muscala': 'ATL',
#  'Mike Scott': 'ATL',
#  'Miles Plumlee': 'MIL',
#  'Mirza Teletovic': 'PHO',
#  'Mitch McGary': 'OKC',
#  'Mo Williams': 'CLE',
#  'Monta Ellis': 'IND',
#  'Montrezl Harrell': 'HOU',
#  'Myles Turner': 'IND',
#  'Nate Robinson': 'ATL',
#  'Nazr Mohammed': 'SAS',
#  'Nemanja Bjelica': 'MIN',
#  'Nene Hilario': 'WAS',
#  'Nerlens Noel': 'PHI',
#  'Nick Collison': 'OKC',
#  'Nick Young': 'LAL',
#  'Nicolas Batum': 'CHO',
#  'Nik Stauskas': 'PHI',
#  'Nikola Jokic': 'DEN',
#  'Nikola Mirotic': 'CHI',
#  'Nikola Pekovic': 'MIN',
#  'Nikola Vucevic': 'ORL',
#  'Noah Vonleh': 'POR',
#  'Norman Powell': 'TOR',
#  'Norris Cole': 'NOP',
#  'O.J. Mayo': 'MIL',
#  'Omer Asik': 'NOP',
#  'Omri Casspi': 'SAC',
#  'Orlando Johnson': 'LAC',
#  'Otto Porter': 'WAS',
#  'P.J. Hairston': 'MIA',
#  'P.J. Tucker': 'PHO',
#  'Pablo Prigioni': 'LAC',
#  'Pat Connaughton': 'POR',
#  'Patrick Beverley': 'HOU',
#  'Patrick Mills': 'SAS',
#  'Patrick Patterson': 'TOR',
#  'Pau Gasol': 'CHI',
#  'Paul George': 'IND',
#  'Paul Millsap': 'ATL',
#  'Paul Pierce': 'LAC',
#  'Phil Pressey': 'DET',
#  'Quincy Acy': 'SAC',
#  'R.J. Hunter': 'BOS',
#  'Rajon Rondo': 'SAC',
#  'Rakeem Christmas': 'IND',
#  'Ramon Sessions': 'WAS',
#  'Randy Foye': 'CLE',
#  'Rashad Vaughn': 'MIL',
#  'Rasual Butler': 'SAS',
#  'Raul Neto': 'UTA',
#  'Ray McCallum': 'CHO',
#  'Raymond Felton': 'DAL',
#  'Reggie Bullock': 'DET',
#  'Reggie Jackson': 'DET',
#  'Richard Jefferson': 'CLE',
#  'Richaun Holmes': 'PHI',
#  'Ricky Rubio': 'MIN',
#  'Robert Covington': 'PHI',
#  'Robert Sacre': 'LAL',
#  'Robin Lopez': 'NYK',
#  'Rodney Hood': 'UTA',
#  'Rodney Stuckey': 'IND',
#  'Rondae Hollis-Jefferson': 'BRK',
#  'Ronnie Price': 'PHO',
#  'Roy Hibbert': 'LAL',
#  'Rudy Gay': 'SAC',
#  'Rudy Gobert': 'UTA',
#  'Russ Smith': 'MEM',
#  'Russell Westbrook': 'MIL',
#  'Ryan Anderson': 'NOP',
#  'Ryan Hollins': 'MEM',
#  'Ryan Kelly': 'LAL',
#  'Salah Mejri': 'DAL',
#  'Sam Dekker': 'HOU',
#  'Sasha Kaun': 'CLE',
#  'Sasha Vujacic': 'NYK',
#  'Sean Kilpatrick': 'DAL',
#  'Serge Ibaka': 'OKC',
#  'Sergey Karasev': 'BRK',
#  'Seth Curry': 'SAC',
#  'Shabazz Muhammad': 'MIN',
#  'Shabazz Napier': 'ORL',
#  'Shane Larkin': 'BRK',
#  'Shaun Livingston': 'GSW',
#  'Shayne Whittington': 'IND',
#  'Shelvin Mack': 'PHI',
#  'Solomon Hill': 'IND',
#  'Sonny Weems': 'BOS',
#  'Spencer Dinwiddie': 'DET',
#  'Spencer Hawes': 'CHO',
#  'Stanley Johnson': 'DET',
#  'Stephen Curry': 'LAL',
#  'Steve Blake': 'DET',
#  'Steve Novak': 'DAL',
#  'Steven Adams': 'OKC',
#  'T.J. McConnell': 'PHI',
#  'T.J. Warren': 'PHO',
#  'Taj Gibson': 'CHI',
#  'Tarik Black': 'LAL',
#  'Tayshaun Prince': 'MIN',
#  'Terrence Jones': 'HOU',
#  'Terrence Ross': 'TOR',
#  'Terry Rozier': 'BOS',
#  'Thabo Sefolosha': 'ATL',
#  'Thaddeus Young': 'BRK',
#  'Thanasis Antetokounmpo': 'NYK',
#  'Thomas Robinson': 'BRK',
#  'Tiago Splitter': 'ATL',
#  'Tibor Pleiss': 'UTA',
#  'Tim Duncan': 'SAS',
#  'Tim Frazier': 'DEN',
#  'Tim Hardaway': 'ATL',
#  'Timofey Mozgov': 'CLE',
#  'Tobias Harris': 'MEM',
#  'Toney Douglas': 'NOP',
#  'Tony Allen': 'MEM',
#  'Tony Parker': 'SAS',
#  'Tony Snell': 'CHI',
#  'Tony Wroten': 'UTA',
#  'Trevor Ariza': 'HOU',
#  'Trevor Booker': 'UTA',
#  'Trey Burke': 'UTA',
#  'Trey Lyles': 'UTA',
#  'Tristan Thompson': 'CLE',
#  'Troy Daniels': 'CHO',
#  'Ty Lawson': 'CHI',
#  'Tyler Ennis': 'LAC',
#  'Tyler Hansbrough': 'CHO',
#  'Tyler Johnson': 'MIA',
#  'Tyler Zeller': 'BOS',
#  'Tyreke Evans': 'NOP',
#  'Tyson Chandler': 'PHO',
#  'Tyus Jones': 'MIN',
#  'Udonis Haslem': 'MIA',
#  'Victor Oladipo': 'ORL',
#  'Vince Carter': 'MEM',
#  'Walter Tavares': 'ATL',
#  'Wayne Ellington': 'BRK',
#  'Wesley Johnson': 'LAC',
#  'Wesley Matthews': 'DAL',
#  'Will Barton': 'DEN',
#  'Willie Cauley-Stein': 'SAC',
#  'Willie Reed': 'BRK',
#  'Xavier Munford': 'MEM',
#  'Zach LaVine': 'MIN',
#  'Zach Randolph': 'MEM',
#  'Zaza Pachulia': 'DAL'}

# %%
df["NewTeam"] = ""

# %%
for p,t in sol_player_assignment.items():
    df["NewTeam"].loc[p]= t
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df["NewTeam"].head()
# Out:
# Player
# Stephen Curry        LAL
# Russell Westbrook    MIL
# LeBron James         PHI
# Kawhi Leonard        BRK
# Kevin Durant         OKC
# Name: NewTeam, dtype: object

# %%
df["NewTeam"][df.NewTeam == "PHI"]
# Out:
# Player
# LeBron James        PHI
# Nerlens Noel        PHI
# Channing Frye       PHI
# Ersan Ilyasova      PHI
# Robert Covington    PHI
# Carl Landry         PHI
# Richaun Holmes      PHI
# Jerami Grant        PHI
# Shelvin Mack        PHI
# T.J. McConnell      PHI
# Isaiah Canaan       PHI
# Hollis Thompson     PHI
# Nik Stauskas        PHI
# Elton Brand         PHI
# Jahlil Okafor       PHI
# Christian Wood      PHI
# Kendall Marshall    PHI
# Name: NewTeam, dtype: object

# %%
len(df.index)
# Out:
# 476

# %%
x = df["NewTeam"]!=df["Tm"]
df[x]
# Out:
#                    Rankweighted   Rk Pos  Age   Tm   G    MP   PER    TS%  \
# Player
# Stephen Curry                 1    1  PG   27  GSW  79  2700  31.5  0.669
# Russell Westbrook             2    2  PG   27  OKC  80  2749  27.6  0.554
# LeBron James                  3    3  SF   31  CLE  76  2709  27.5  0.588
# Kawhi Leonard                 4    7  SF   24  SAS  72  2380  26.0  0.616
# Chris Paul                    6    8  PG   30  LAC  74  2420  26.2  0.575
# James Ennis                  34  184  SF   25  TOT  22   329  17.8  0.621
# David Lee                    77  138  PF   32  TOT  55   903  19.6  0.568
# Mario Chalmers               81  110  PG   29  TOT  61  1373  17.2  0.561
# Tobias Harris               102   61  PF   23  TOT  76  2513  16.2  0.560
# Chris Andersen              105  203   C   37  TOT  27   402  15.3  0.598
# Jason Thompson              126  204   C   29  TOT  47   471  14.2  0.558
# Channing Frye               137  150  PF   32  TOT  70  1200  12.9  0.586
# Ersan Ilyasova              153  125  PF   28  TOT  74  1881  14.2  0.526
# Courtney Lee                188  137  SG   30  TOT  79  2334  11.5  0.551
# Shelvin Mack                228  229  PG   25  TOT  52  1058  13.6  0.507
# Joe Johnson                 245  197  SF   34  TOT  81  2703  12.0  0.538
# Lance Stephenson            246  234  SF   25  TOT  69  1372  13.5  0.548
# Tim Frazier                 251  249  PG   25  TOT  51   741  13.9  0.499
# Brandon Jennings            253  252  PG   26  TOT  48   868  13.7  0.491
# Chase Budinger              255  259  SF   27  TOT  66   929  10.7  0.514
# Jeff Green                  257  237  SF   29  TOT  80  2253  13.0  0.510
# D.J. Augustin               258  258  PG   28  TOT  62  1178  13.9  0.575
# Ish Smith                   264  261  PG   27  TOT  77  2239  14.9  0.465
# Jarnell Stokes              268  270   C   22  TOT   7    18  20.0  0.595
# Erick Green                 274  277  PG   24  TOT   9    42  12.4  0.468
# Anderson Varejao            281  289   C   33  TOT  53   496  11.1  0.473
# Ryan Hollins                282  273   C   31  TOT  37   460  12.3  0.636
# Marcus Thornton             291  284  SG   28  TOT  61  1109  14.7  0.511
# Alex Stepheson              295  299  PF   28  TOT   8    73  14.8  0.341
# Briante Weber               306  285  PG   23  TOT   7   169   8.9  0.380
# ...                         ...  ...  ..  ...  ...  ..   ...   ...    ...
# Andre Miller                341  331  PG   39  TOT  39   461  13.4  0.600
# J.J. Hickson                344  332   C   27  TOT  35   436  16.8  0.514
# Kris Humphries              347  371  PF   30  TOT  53   835  13.1  0.517
# Gerald Green                350  417  SG   30  MIA  69  1557  10.1  0.491
# Sean Kilpatrick             368  373  SG   26  TOT  31   616  15.6  0.576
# Randy Foye                  375  450  SG   32  TOT  81  1642   7.6  0.461
# Ray McCallum                387  379  PG   24  TOT  41   475   9.1  0.449
# Brian Roberts               388  380  PG   30  TOT  51   470  13.8  0.552
# Kirk Hinrich                390  407  PG   35  TOT  46   631   7.2  0.504
# Jordan McRae                398  340  PG   24  TOT  22   195  14.2  0.548
# P.J. Hairston               402  458  SF   23  TOT  66  1313   6.9  0.470
# Ty Lawson                   418  470  PG   28  TOT  66  1411   9.7  0.476
# Kevin Martin                419  459  SG   32  TOT  55  1095  11.5  0.520
# Beno Udrih                  426  444  PG   33  TOT  44   707   9.5  0.496
# Tyler Ennis                 429  443  PG   21  MIL  46   654  10.7  0.510
# John Jenkins                433  432  SG   24  TOT  43   480  10.0  0.522
# JaKarr Sampson              436  474  SF   22  TOT  73  1160   8.3  0.504
# Jared Cunningham            441  433  SG   24  TOT  44   410   5.9  0.464
# Phil Pressey                448  415  PG   24  TOT  23   283  10.6  0.433
# Cleanthony Early            456  394  SF   24  NYK  17   154   2.2  0.371
# Sonny Weems                 460  463  SG   29  TOT  43   499   3.7  0.459
# Orlando Johnson             465  397  SG   26  TOT   7   101   3.2  0.337
# Cory Jefferson              466  361  PF   25  PHO   8    50  12.7  0.446
# Steve Novak                 468  349  PF   32  TOT  10    44  14.4  0.651
# Bryce Cotton                471  358  PG   23  TOT   8    39   1.7  0.400
# Tony Wroten                 472  435  PG   22  PHI   8   144   1.8  0.412
# Keith Appling               473  359  PG   23  ORL   5    27  -4.8  0.338
# Nate Robinson               474  356  PG   31  NOP   2    23   2.6  0.000
# Luis Montero                475  398  SG   22  POR  12    42  -2.7  0.337
# Nazr Mohammed               476  360   C   38  OKC   5    19   6.0  0.680
#
#                     3PAr   ...      OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  \
# Player                     ...
# Stephen Curry      0.554   ...     13.8  4.1  17.9  0.318  12.4   0.1  12.4
# Russell Westbrook  0.236   ...     10.0  4.0  14.0  0.245   7.6   2.4  10.0
# LeBron James       0.199   ...      9.6  4.0  13.6  0.242   6.9   2.3   9.1
# Kawhi Leonard      0.267   ...      8.3  5.5  13.7  0.277   5.5   2.8   8.3
# Chris Paul         0.295   ...      9.2  3.5  12.7  0.253   7.3   0.5   7.8
# James Ennis        0.513   ...      0.7  0.2   0.9  0.133   3.4  -1.0   2.4
# David Lee          0.003   ...      1.7  1.4   3.0  0.161  -0.3   1.7   1.4
# Mario Chalmers     0.336   ...      2.2  1.5   3.8  0.131   1.7  -0.3   1.5
# Tobias Harris      0.269   ...      4.1  2.5   6.6  0.126   0.7   0.4   1.0
# Chris Andersen     0.194   ...      0.8  0.4   1.3  0.149  -0.3   1.1   0.8
# Jason Thompson     0.139   ...      0.9  0.7   1.6  0.165  -1.3   1.6   0.3
# Channing Frye      0.677   ...      1.6  1.3   3.0  0.119   0.5   0.0   0.5
# Ersan Ilyasova     0.392   ...      2.4  2.0   4.4  0.113   0.4  -0.3   0.1
# Courtney Lee       0.340   ...      2.1  1.8   3.9  0.080  -0.4  -0.1  -0.5
# Shelvin Mack       0.301   ...      0.2  1.2   1.3  0.061  -0.5  -0.8  -1.2
# Joe Johnson        0.364   ...      1.9  0.8   2.7  0.048   0.3  -1.6  -1.3
# Lance Stephenson   0.165   ...      0.9  1.3   2.2  0.076  -1.1  -0.3  -1.4
# Tim Frazier        0.210   ...      0.4  0.5   1.0  0.062  -0.7  -0.7  -1.3
# Brandon Jennings   0.510   ...      0.8  0.7   1.5  0.082   0.3  -1.7  -1.4
# Chase Budinger     0.360   ...      0.4  1.0   1.4  0.073  -2.0   0.3  -1.7
# Jeff Green         0.258   ...      1.3  1.7   3.1  0.065  -1.0  -0.7  -1.7
# D.J. Augustin      0.480   ...      2.0  0.6   2.6  0.106   1.0  -2.7  -1.7
# Ish Smith          0.176   ...      0.0  1.3   1.3  0.027  -0.6  -1.1  -1.7
# Jarnell Stokes     0.000   ...      0.1  0.0   0.1  0.209  -0.1  -1.0  -1.0
# Erick Green        0.385   ...      0.1  0.0   0.1  0.121   0.1  -2.2  -2.0
# Anderson Varejao   0.008   ...      0.3  0.8   1.0  0.101  -3.8   1.4  -2.4
# Ryan Hollins       0.000   ...      0.6  0.3   1.0  0.100  -2.0   0.2  -1.8
# Marcus Thornton    0.498   ...      1.0  0.7   1.7  0.074   0.7  -2.9  -2.1
# Alex Stepheson     0.000   ...      0.0  0.1   0.1  0.068  -2.0  -1.1  -3.2
# Briante Weber      0.128   ...     -0.2  0.2   0.0  0.004  -3.6   1.5  -2.1
# ...                  ...   ...      ...  ...   ...    ...   ...   ...   ...
# Andre Miller       0.075   ...      0.6  0.4   1.0  0.100  -1.1  -1.8  -2.9
# J.J. Hickson       0.006   ...      0.3  0.5   0.8  0.088  -2.9  -0.1  -3.0
# Kris Humphries     0.366   ...      0.5  1.1   1.6  0.093  -2.2  -0.7  -2.9
# Gerald Green       0.443   ...      0.3  1.4   1.7  0.052  -1.2  -1.8  -3.0
# Sean Kilpatrick    0.422   ...      1.0  0.0   1.0  0.076   1.4  -4.4  -3.0
# Randy Foye         0.519   ...     -0.4  0.9   0.4  0.012  -2.3  -1.3  -3.5
# Ray McCallum       0.288   ...     -0.2  0.5   0.3  0.034  -2.9  -0.8  -3.7
# Brian Roberts      0.255   ...      0.7  0.3   1.0  0.105  -1.1  -2.8  -3.9
# Kirk Hinrich       0.481   ...      0.1  0.5   0.6  0.044  -2.7  -1.0  -3.7
# Jordan McRae       0.282   ...      0.2  0.1   0.4  0.087  -0.9  -3.3  -4.3
# P.J. Hairston      0.591   ...     -0.6  1.1   0.6  0.021  -2.7  -1.5  -4.2
# Ty Lawson          0.305   ...      0.2  0.7   0.9  0.031  -2.7  -2.0  -4.6
# Kevin Martin       0.325   ...      0.7  0.5   1.2  0.054  -1.4  -3.1  -4.5
# Beno Udrih         0.222   ...     -0.1  0.5   0.4  0.029  -2.8  -2.0  -4.8
# Tyler Ennis        0.209   ...      0.1  0.3   0.4  0.030  -2.4  -2.3  -4.8
# John Jenkins       0.319   ...      0.0  0.2   0.2  0.022  -3.0  -2.4  -5.4
# JaKarr Sampson     0.199   ...     -0.5  0.6   0.1  0.006  -4.6  -0.8  -5.4
# Jared Cunningham   0.371   ...     -0.3  0.4   0.1  0.014  -4.6  -1.3  -5.9
# Phil Pressey       0.231   ...     -0.4  0.3  -0.1 -0.017  -4.8  -1.5  -6.4
# Cleanthony Early   0.375   ...     -0.3  0.1  -0.2 -0.075  -7.1  -1.1  -8.2
# Sonny Weems        0.373   ...     -0.7  0.1  -0.5 -0.053  -5.7  -1.8  -7.6
# Orlando Johnson    0.286   ...     -0.3  0.1  -0.2 -0.096  -8.3  -2.5 -10.8
# Cory Jefferson     0.045   ...      0.0  0.0   0.1  0.070  -6.1  -7.7 -13.8
# Steve Novak        0.833   ...      0.1  0.0   0.1  0.121   1.3  -8.0  -6.6
# Bryce Cotton       0.300   ...     -0.2  0.0  -0.1 -0.168  -9.3  -2.7 -12.0
# Tony Wroten        0.262   ...     -0.8  0.0  -0.8 -0.263  -9.9  -3.5 -13.4
# Keith Appling      0.375   ...     -0.1  0.0  -0.1 -0.199 -10.3  -2.7 -13.0
# Nate Robinson      1.000   ...      0.0  0.0   0.0  0.038  -6.1  -4.7 -10.8
# Luis Montero       0.474   ...     -0.2  0.0  -0.2 -0.238 -11.0  -5.9 -16.9
# Nazr Mohammed      0.000   ...      0.0  0.0   0.0 -0.009  -7.4  -5.9 -13.2
#
#                    VORP  VORPpermin  NewTeam
# Player
# Stephen Curry       9.8    0.003630      LAL
# Russell Westbrook   8.3    0.003019      MIL
# LeBron James        7.6    0.002805      PHI
# Kawhi Leonard       6.2    0.002605      BRK
# Chris Paul          6.0    0.002479      LAL
# James Ennis         0.4    0.001216      MIL
# David Lee           0.8    0.000886      MIN
# Mario Chalmers      1.2    0.000874      MIN
# Tobias Harris       1.9    0.000756      MEM
# Chris Andersen      0.3    0.000746      NYK
# Jason Thompson      0.3    0.000637      ORL
# Channing Frye       0.7    0.000583      PHI
# Ersan Ilyasova      1.0    0.000532      PHI
# Courtney Lee        0.9    0.000386      MIN
# Shelvin Mack        0.2    0.000189      PHI
# Joe Johnson         0.4    0.000148      ORL
# Lance Stephenson    0.2    0.000146      OKC
# Tim Frazier         0.1    0.000135      DEN
# Brandon Jennings    0.1    0.000115      OKC
# Chase Budinger      0.1    0.000108      WAS
# Jeff Green          0.2    0.000089      MEM
# D.J. Augustin       0.1    0.000085      WAS
# Ish Smith           0.1    0.000045      WAS
# Jarnell Stokes      0.0    0.000000      GSW
# Erick Green         0.0    0.000000      OKC
# Anderson Varejao    0.0    0.000000      ATL
# Ryan Hollins        0.0    0.000000      MEM
# Marcus Thornton     0.0    0.000000      IND
# Alex Stepheson      0.0    0.000000      OKC
# Briante Weber       0.0    0.000000      POR
# ...                 ...         ...      ...
# Andre Miller       -0.1   -0.000217      LAC
# J.J. Hickson       -0.1   -0.000229      SAS
# Kris Humphries     -0.2   -0.000240      SAS
# Gerald Green       -0.4   -0.000257      CHI
# Sean Kilpatrick    -0.2   -0.000325      DAL
# Randy Foye         -0.6   -0.000365      CLE
# Ray McCallum       -0.2   -0.000421      CHO
# Brian Roberts      -0.2   -0.000426      TOR
# Kirk Hinrich       -0.3   -0.000475      CLE
# Jordan McRae       -0.1   -0.000513      SAC
# P.J. Hairston      -0.7   -0.000533      MIA
# Ty Lawson          -0.9   -0.000638      CHI
# Kevin Martin       -0.7   -0.000639      CLE
# Beno Udrih         -0.5   -0.000707      CLE
# Tyler Ennis        -0.5   -0.000765      LAC
# John Jenkins       -0.4   -0.000833      POR
# JaKarr Sampson     -1.0   -0.000862      CHO
# Jared Cunningham   -0.4   -0.000976      CHO
# Phil Pressey       -0.3   -0.001060      DET
# Cleanthony Early   -0.2   -0.001299      TOR
# Sonny Weems        -0.7   -0.001403      BOS
# Orlando Johnson    -0.2   -0.001980      LAC
# Cory Jefferson     -0.1   -0.002000      IND
# Steve Novak        -0.1   -0.002273      DAL
# Bryce Cotton       -0.1   -0.002564      MIA
# Tony Wroten        -0.4   -0.002778      UTA
# Keith Appling      -0.1   -0.003704      GSW
# Nate Robinson      -0.1   -0.004348      ATL
# Luis Montero       -0.2   -0.004762      SAS
# Nazr Mohammed      -0.1   -0.005263      SAS
#
# [64 rows x 29 columns]
